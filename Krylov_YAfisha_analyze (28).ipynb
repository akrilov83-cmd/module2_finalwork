# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Андрей, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# Целью данного проекта является помощь команде маркетинга в лучшем понимании поведения пользователей Яндекс Афиши.
# Для этого проводится исследовательский анализ данных на предмет того, какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно.
# Это позволит:
#  - Быстро выявлять перспективных клиентов и предлагать им персонализированные условия.
#  - Точно настраивать рекламу на аудитории с высокой вероятностью возврата.
#  - Оптимизировать маркетинговые бюджеты.
#  - Повысить общий уровень удержания клиентов.
#
# Используемые данные:
# - **Витрина заказов Яндекс Афиши** - витрина данных, собранная SQL-запросом (используя библиотеку SQLAlchemy) в базе данных Яндекс Афиши `data-analyst-afisha`.
# - **CSV-файл в сети с курсом казахского тенге** по отношению к российскому рублю за 2024 год (значения для 100 казахских тенге).
#
# В процессе исследования получим ответ на следующие вопросы (проверим гипотезы):
#  - Равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#  - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу? Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#  - Опираясь на ранее сделанные выводы, проверим продуктовые гипотезы:
#   - Гипотеза 1. Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
#   - Гипотеза 2. В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#  - Проследим связь между средней выручкой сервиса с заказа и повторными заказами.Ответим на вопросы:
#   - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#   - Есть ли различия между группами?
#  - Сравним распределение по средней выручке с заказа в двух группах пользователей: совершившие 2–4 заказа, совершившие 5 и более заказов. Ответим на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#  - Проанализируем влияние среднего количества билетов в заказе на вероятность повторной покупки. Изучем распределение пользователей по среднему количеству билетов в заказе (от 1 до 2 билетов, от 2 до 3 билетов, от 3 до 5 билетов, от 5 и более билетов) и опишем основные наблюдения. Ответим на вопросы:
#   - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#   - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#  - Изучим временные параметры, связанные с первым заказом пользователей: день недели первой покупки, время с момента первой покупки — лайфтайм, средний интервал между покупками пользователей с повторными заказами.
#   - Проанализируем, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей. Ответим на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#   - Изучим, как средний интервал между заказами влияет на удержание клиентов и опишем сделанные выводы.
#  - Проведем корреляционный анализ: рассчитаем коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов. Ответим на вопрос: какие признаки наиболее связаны с количеством заказов?

# %% [markdown]
# ## Этапы выполнения проекта
#
# 1. Загрузка данных и их предобработка (загрузка и первичное исследование и проверка данных Яндекс Афиши).
# 2. Предобработка данных (приведение валюты к российским рублям и обработка типов данных, пропусков, дубликатов).
# 3. Создание профиля пользователя (создание модели для прогнозирования возврата пользователей, построиение агрегированных признаков, описывающих поведение и профиль каждого пользователя).
# 4. Исследовательский анализ данных (исследование признаков, влияющих на возврат пользователей).
# 5. Общие выводы и рекомендации.
#
# ### 1. Загрузка данных и их предобработка
#
# **Первый источник данных** - витрина данных, собранная SQL-запросом (используя библиотеку SQLAlchemy) в базе данных Яндекс Афиши `data-analyst-afisha`.
# Витрина данных содержит следующие признаки:
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
# !pip install phik
# !pip install dotenv
# Out:
# Requirement already satisfied: phik in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (0.12.5)
# Requirement already satisfied: numpy>=1.18.0 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from phik) (2.3.4)
# Requirement already satisfied: scipy>=1.5.2 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from phik) (1.16.3)
# Requirement already satisfied: pandas>=0.25.1 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from phik) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2.3 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from phik) (3.10.7)
# Requirement already satisfied: joblib>=0.14.1 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from phik) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (25.0)
# Requirement already satisfied: pillow>=8 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from matplotlib>=2.2.3->phik) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from pandas>=0.25.1->phik) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from pandas>=0.25.1->phik) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.17.0)
# Requirement already satisfied: dotenv in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in d:\ds\modele2_finalwork\module2_finalwork\lib\site-packages (from dotenv) (1.2.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import phik
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %%
load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")

connection_string = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"

# %%
engine = create_engine(connection_string)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!

# %%
query = '''
SELECT 
    user_id,
    device_type_canonical,
    order_id,
    created_dt_msk as order_dt,
    created_ts_msk as order_ts,
    currency_code,
    revenue,
    tickets_count,
    created_dt_msk::date - LAG(created_dt_msk::date) OVER(PARTITION BY user_id ORDER BY created_dt_msk ASC) AS days_since_prev,
    event_id,
    service_name,
    event_type_main,
    region_name,
    city_name
FROM afisha.purchases
    INNER JOIN afisha.events as e USING(event_id)
    INNER JOIN afisha.city USING(city_id)
    INNER JOIN afisha.regions USING(region_id)
WHERE device_type_canonical IN ('desktop', 'mobile') AND e.event_type_main <> 'фильм'

'''

df = pd.read_sql_query(query, con=engine)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные из запроса загружены.

# %% [markdown]
# Проведем первичный анализ загруженных данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  service_name           290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  region_name            290611 non-null  object
#  13  city_name              290611 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(7)
# memory usage: 31.0+ MB

# %%
df.head(10)
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
# 5  000898990054619                mobile   2613713 2024-10-23
# 6  00096d1f542ab2b               desktop   6636941 2024-08-15
# 7  000a55a418c128c                mobile   4657981 2024-09-29
# 8  000a55a418c128c                mobile   4657952 2024-10-15
# 9  000cf0659a9f40f                mobile   6818191 2024-06-20
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
# 5 2024-10-23 15:12:00           rub   902.74              3             19.0
# 6 2024-08-15 16:48:48           rub   917.83              4              NaN
# 7 2024-09-29 19:39:12           rub    47.78              1              NaN
# 8 2024-10-15 10:29:04           rub    74.84              2             16.0
# 9 2024-06-20 10:51:10           rub  1421.91              4              NaN
#
#    event_id        service_name event_type_main           region_name  \
# 0    169230        Край билетов           театр    Каменевский регион
# 1    237325           Мой билет        выставки    Каменевский регион
# 2    578454         За билетом!          другое    Каменевский регион
# 3    387271         Лови билет!          другое  Североярская область
# 4    509453  Билеты без проблем         стендап      Озернинский край
# 5    500862             Облачко        концерты  Лугоградская область
# 6    201953        Край билетов           театр    Каменевский регион
# 7    265857       Лучшие билеты           театр      Поленовский край
# 8    271579       Лучшие билеты           театр      Поленовский край
# 9    516728         Лови билет!        концерты   Широковская область
#
#        city_name
# 0     Глиногорск
# 1     Глиногорск
# 2     Глиногорск
# 3         Озёрск
# 4    Родниковецк
# 5    Кристалевск
# 6     Глиногорск
# 7  Дальнозолотск
# 8  Дальнозолотск
# 9   Радужнополье

# %% [markdown]
# Изучим пропуски в колонке `days_since_prev`

# %%
df['days_since_prev'].value_counts(dropna=False)
# Out:
# days_since_prev
# 0.0      184052
# 1.0       30472
# NaN       21933
# 2.0        9947
# 3.0        6182
#           ...
# 148.0         3
# 143.0         3
# 147.0         3
# 141.0         2
# 140.0         1
# Name: count, Length: 150, dtype: int64

# %% [markdown]
# Оценим долю пропусков к колонке `days_since_prev`

# %%
df['days_since_prev'].isna().sum() / df.shape[0]
# Out:
# np.float64(0.07547202273829966)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пропуски проверены.

# %% [markdown]
# Изучим типы данных в колонках `order_id`, `event_id`

# %%
df['order_id'].min()
# Out:
# np.int64(1)

# %%
df['order_id'].max()
# Out:
# np.int64(8653108)

# %%
df['event_id'].min()
# Out:
# np.int64(4436)

# %%
df['event_id'].max()
# Out:
# np.int64(592325)

# %% [markdown]
# Проверим уникальные значения в категориальных столбцах

# %%
categorical_cols = [
    'device_type_canonical',
    'currency_code',
    'service_name',
    'event_type_main',
    'region_name',
    'city_name'
]

for col in categorical_cols:
    print(f"{col} количество уникальных значений: {df[col].nunique()}")
    print(f"{col} количество пропусков: {df[col].isna().sum()}")
    print(f"{col} количество уникальных значений с нормализацией данных: {df[col].str.lower().nunique()}")
    print(f"{col} частота уникальных значений: {df[col].value_counts(dropna=False)}")
    print(f"{col}: {sorted(df[col].unique())}")
# Out:
# device_type_canonical количество уникальных значений: 2
# device_type_canonical количество пропусков: 0
# device_type_canonical количество уникальных значений с нормализацией данных: 2
# device_type_canonical частота уникальных значений: device_type_canonical
# mobile     232490
# desktop     58121
# Name: count, dtype: int64
# device_type_canonical: ['desktop', 'mobile']
# currency_code количество уникальных значений: 2
# currency_code количество пропусков: 0
# currency_code количество уникальных значений с нормализацией данных: 2
# currency_code частота уникальных значений: currency_code
# rub    285542
# kzt      5069
# Name: count, dtype: int64
# currency_code: ['kzt', 'rub']
# service_name количество уникальных значений: 36
# service_name количество пропусков: 0
# service_name количество уникальных значений с нормализацией данных: 36
# service_name частота уникальных значений: service_name
# Билеты без проблем        63519
# Лови билет!               41124
# Билеты в руки             40343
# Мой билет                 34839
# Облачко                   26642
# Лучшие билеты             17774
# Весь в билетах            16849
# Прачечная                 10273
# Край билетов               6207
# Тебе билет!                5228
# Яблоко                     5039
# Дом культуры               4502
# За билетом!                2865
# Городской дом культуры     2733
# Show_ticket                2200
# Мир касс                   2167
# Быстробилет                2003
# Выступления.ру             1616
# Восьмёрка                  1118
# Crazy ticket!               790
# Росбилет                    539
# Шоу начинается!             499
# Быстрый кассир              381
# Радио ticket                376
# Телебилет                   321
# КарандашРУ                  133
# Реестр                      125
# Билет по телефону            85
# Вперёд!                      80
# Дырокол                      74
# Кино билет                   67
# Цвет и билет                 61
# Тех билет                    22
# Лимоны                        8
# Зе Бест!                      5
# Билеты в интернете            4
# Name: count, dtype: int64
# service_name: ['Crazy ticket!', 'Show_ticket', 'Билет по телефону', 'Билеты без проблем', 'Билеты в интернете', 'Билеты в руки', 'Быстробилет', 'Быстрый кассир', 'Весь в билетах', 'Восьмёрка', 'Вперёд!', 'Выступления.ру', 'Городской дом культуры', 'Дом культуры', 'Дырокол', 'За билетом!', 'Зе Бест!', 'КарандашРУ', 'Кино билет', 'Край билетов', 'Лимоны', 'Лови билет!', 'Лучшие билеты', 'Мир касс', 'Мой билет', 'Облачко', 'Прачечная', 'Радио ticket', 'Реестр', 'Росбилет', 'Тебе билет!', 'Телебилет', 'Тех билет', 'Цвет и билет', 'Шоу начинается!', 'Яблоко']
# event_type_main количество уникальных значений: 7
# event_type_main количество пропусков: 0
# event_type_main количество уникальных значений с нормализацией данных: 7
# event_type_main частота уникальных значений: event_type_main
# концерты    115276
# театр        67321
# другое       65867
# спорт        21911
# стендап      13393
# выставки      4854
# ёлки          1989
# Name: count, dtype: int64
# event_type_main: ['выставки', 'другое', 'концерты', 'спорт', 'стендап', 'театр', 'ёлки']
# region_name количество уникальных значений: 81
# region_name количество пропусков: 0
# region_name количество уникальных значений с нормализацией данных: 81
# region_name частота уникальных значений: region_name
# Каменевский регион          91058
# Североярская область        44049
# Широковская область         16457
# Медовская область           13901
# Озернинский край            10476
#                             ...
# Лесноярский край               19
# Крутоводский регион            18
# Верхозёрский край              11
# Сосноводолинская область       10
# Теплоозёрский округ             7
# Name: count, Length: 81, dtype: int64
# region_name: ['Белоярская область', 'Берестовский округ', 'Берёзовская область', 'Боровлянский край', 'Верховинская область', 'Верхозёрский край', 'Верхоречная область', 'Ветренский регион', 'Вишнёвский край', 'Глиногорская область', 'Голубевский округ', 'Горицветская область', 'Горноземский регион', 'Горностепной регион', 'Дальнеземская область', 'Дальнезорский край', 'Дубравная область', 'Залесский край', 'Заречная область', 'Зеленоградский округ', 'Златопольский округ', 'Золотоключевской край', 'Зоринский регион', 'Каменевский регион', 'Каменичская область', 'Каменноозёрный край', 'Каменноярский край', 'Каменополянский округ', 'Ключеводский округ', 'Кристаловская область', 'Кристальная область', 'Крутоводская область', 'Крутоводский регион', 'Лесноярский край', 'Лесодальний край', 'Лесополянская область', 'Лесостепной край', 'Лесоярская область', 'Луговая область', 'Лугоградская область', 'Малиновая область', 'Малиновоярский округ', 'Медовская область', 'Миропольская область', 'Нежинская область', 'Озернинский край', 'Озернопольская область', 'Островная область', 'Островогорский округ', 'Поленовский край', 'Радужногорская область', 'Радужнопольский край', 'Речиновская область', 'Речицкая область', 'Речицкий регион', 'Ручейковский край', 'Светолесский край', 'Светополянский округ', 'Североключевской округ', 'Североозёрский округ', 'Североярская область', 'Серебринская область', 'Серебряноярский округ', 'Синегорский регион', 'Солнечноземская область', 'Солнечнореченская область', 'Сосноводолинская область', 'Сосновская область', 'Теплоозёрский округ', 'Тепляковская область', 'Тихогорская область', 'Тихолесский край', 'Тихореченская область', 'Травиницкий округ', 'Травяная область', 'Чистогорская область', 'Шанырский регион', 'Широковская область', 'Яблоневская область', 'Ягодиновская область', 'Яснопольский округ']
# city_name количество уникальных значений: 352
# city_name количество пропусков: 0
# city_name количество уникальных значений с нормализацией данных: 352
# city_name частота уникальных значений: city_name
# Глиногорск      89446
# Озёрск          43910
# Радужсвет       13711
# Радужнополье     8741
# Верховино        6579
#                 ...
# Реченогор           1
# Кристолесье         1
# Озёроярск           1
# Байсары             1
# Солнечегорск        1
# Name: count, Length: 352, dtype: int64
# city_name: ['Айкольск', 'Айсуак', 'Акбастау', 'Акбасты', 'Акжолтау', 'Алтынкала', 'Алтынсай', 'Байкуль', 'Байсары', 'Байтерековск', 'Беловодск', 'Белоярск', 'Бережанка', 'Бережанск', 'Березиногорск', 'Березиноск', 'Березовцево', 'Берестовец', 'Берестяград', 'Берёзиново', 'Берёзовка', 'Берёзогорск', 'Берёзодальн', 'Берёзополье', 'Берёзореч', 'Берёзоречье', 'Бозарык', 'Боровлянск', 'Буркиттау', 'Бурьяново', 'Верховино', 'Верховка', 'Верхозолотск', 'Верхозорье', 'Верхоозёров', 'Ветеринск', 'Вишнёво', 'Вишнёвогорск', 'Вишнёводск', 'Водниково', 'Глиногорск', 'Глиногорь', 'Глиноград', 'Глинозолото', 'Глинозорь', 'Глинолес', 'Глинополин', 'Глинополье', 'Глинополянск', 'Глинореч', 'Глинянск', 'Голубевск', 'Голубино', 'Гореловск', 'Горицветск', 'Горноград', 'Горнодолинск', 'Горнолесье', 'Горнолуг', 'Горнополец', 'Горнополье', 'Горнополянск', 'Горнополяровск', 'Горнополёк', 'Горноставинск', 'Горяново', 'Дальнеград', 'Дальнесветин', 'Дальнесветск', 'Дальнесоснов', 'Дальнозелен', 'Дальнозерск', 'Дальнозолотск', 'Дальнолесье', 'Дальнополин', 'Долиновка', 'Долиновск', 'Жаркентай', 'Желкаин', 'Желтау', 'Желтоксан', 'Жетисайск', 'Зареченец', 'Заречийск', 'Заречиновка', 'Заречинск', 'Заречка', 'Заречнаярово', 'Заречник', 'Заречнинск', 'Зеленогорье', 'Зеленоградовск', 'Зеленолесье', 'Зеленополец', 'Зеленополин', 'Зеленополье', 'Зелёнаярово', 'Зелёново', 'Зелёнояр', 'Златоозёрово', 'Златополье', 'Златопольск', 'Златоречинск', 'Златоречье', 'Зоревец', 'Зоревичск', 'Зореполин', 'Зоречанск', 'Зориново', 'Каменевовск', 'Каменевск', 'Каменевский', 'Каменичи', 'Каменогорский', 'Каменогорье', 'Каменодолин', 'Каменозолото', 'Каменосветск', 'Каменояр', 'Каменский', 'Каменёвка', 'Каражар', 'Каражол', 'Карасуй', 'Карасуйск', 'Кенесар', 'Ключевинск', 'Ключевогорск', 'Ключеводск', 'Ключевополье', 'Ключеград', 'Ключезолотск', 'Кокжар', 'Коксуйск', 'Кристалевск', 'Кристалин', 'Кристалинск', 'Кристаловец', 'Кристаловка', 'Кристальевка', 'Кристолесье', 'Крутовинск', 'Крутовичи', 'Крутово', 'Крутоводинск', 'Крутоводск', 'Кумсай', 'Кумсары', 'Кызылжол', 'Лесиново', 'Лесинск', 'Леснойск', 'Лесоводск', 'Лесогорич', 'Лесогорск', 'Лесогорский', 'Лесодолинск', 'Лесозерск', 'Лесозолотск', 'Лесополин', 'Лесореченск', 'Лесочистка', 'Лесоярич', 'Лесоярка', 'Лесоярово', 'Лугиново', 'Луговаярово', 'Луговинец', 'Луговинск', 'Луговское', 'Лугоград', 'Луновка', 'Малиновец', 'Малиновецк', 'Малиновинск', 'Малиноворск', 'Малиновочист', 'Медвежанск', 'Медвежиновск', 'Медвежник', 'Медовецк', 'Медовино', 'Мироград', 'Миролесье', 'Мирополь', 'Миросветск', 'Мироярово', 'Нежинск', 'Нивинск', 'Никольянов', 'Нуртас', 'Озёречин', 'Озёриново', 'Озёрово', 'Озёроград', 'Озёроярск', 'Озёрск', 'Озёрчане', 'Озёряновск', 'Ордакент', 'Ордасай', 'Островенск', 'Островецк', 'Острововск', 'Островозёров', 'Островополь', 'Островсков', 'Островской', 'Островярово', 'Песковино', 'Песчанец', 'Песчанская', 'Поленовец', 'Поленовино', 'Поленовичи', 'Поленоград', 'Поленолесье', 'Поленоозёрово', 'Поленосвет', 'Поленосветск', 'Поленояр', 'Поляновск', 'Поляногорье', 'Поляноречинск', 'Полянск', 'Радугорь', 'Радужанов', 'Радужинск', 'Радужнаярова', 'Радужновка', 'Радужнополье', 'Радужнояр', 'Радужовинск', 'Радужсвет', 'Речевинец', 'Реченогор', 'Реченск', 'Речепольск', 'Речиноград', 'Речинск', 'Речинцево', 'Речичанск', 'Речное', 'Родинсветск', 'Родниковец', 'Родниковецк', 'Родниковск', 'Родничанск', 'Рощино', 'Ручейковск', 'Ручейник', 'Ручейницк', 'Ручейновинск', 'Ручейный', 'Ручьевино', 'Сарыбулак', 'Сарыжар', 'Сарытау', 'Светлоярск', 'Светогория', 'Светозолотск', 'Светозорск', 'Светозёринск', 'Светополь', 'Светополье', 'Светоречин', 'Светочистенск', 'Светочистка', 'Светоярич', 'Светоярово', 'Светоярчик', 'Северобережье', 'Северогорск', 'Североград', 'Северополье', 'Серебринск', 'Серебровино', 'Серебровка', 'Сереброяр', 'Серебрянка', 'Синеводов', 'Синеводск', 'Синегориново', 'Синегорск', 'Синеполинск', 'Солнечеводск', 'Солнечегорск', 'Солнечеград', 'Солнечейск', 'Солнечелесье', 'Солнечеполье', 'Солнечнёвка', 'Солнеч ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Категориальные признаки проверены на предмет аномалий.

# %% [markdown]
# Проверим полные дубликаты:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Полных дубликатов нет

# %% [markdown]
# Проверим дубликаты по отдельным колонкам (наборм колонок):

# %%
# Проверим дубликаты по столбцу order_id
print(f"Количество дубликатов в столбце order_id: {df.duplicated(subset=['order_id']).sum()}")
# Out:
# Количество дубликатов в столбце order_id: 0

# %% [markdown]
# Дубликатов заказов нет

# %% [markdown]
# Проверим дубликаты по набору столбцов user_id, order_ts, revenue_rub, event_id (подозрительные дубликаты):

# %%
#Проверим дубликаты по столбцам user_id, order_ts, revenue_rub, event_id
df[df.duplicated(subset=['user_id', 'order_ts', 'revenue', 'event_id'], keep=False)].sort_values(by=['user_id', 'order_ts', 'revenue', 'event_id'])
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 11758   06eb7897f65b433                mobile   1123983 2024-08-13
# 11759   06eb7897f65b433                mobile   1123867 2024-08-13
# 12677   08199117318954f               desktop   5592970 2024-07-31
# 12678   08199117318954f                mobile   5593202 2024-07-31
# 26868   0dc525d7bacbb0d               desktop   1930763 2024-07-31
# ...                 ...                   ...       ...        ...
# 285379  fd4d47438ebb946               desktop   8548099 2024-06-19
# 285388  fd4d47438ebb946               desktop   8547809 2024-06-19
# 285375  fd4d47438ebb946               desktop   8547867 2024-06-19
# 285382  fd4d47438ebb946               desktop   8548012 2024-06-19
# 285383  fd4d47438ebb946               desktop   8547983 2024-06-19
#
#                   order_ts currency_code  revenue  tickets_count  \
# 11758  2024-08-13 16:31:07           rub    69.82              1
# 11759  2024-08-13 16:31:07           rub    69.82              1
# 12677  2024-07-31 11:52:06           rub     0.00              3
# 12678  2024-07-31 11:52:06           rub     0.00              3
# 26868  2024-07-31 13:26:11           rub  1556.05              3
# ...                    ...           ...      ...            ...
# 285379 2024-06-19 15:40:56           rub   989.57              3
# 285388 2024-06-19 15:40:56           rub   989.57              3
# 285375 2024-06-19 15:40:56           rub  1319.43              4
# 285382 2024-06-19 15:40:56           rub  1319.43              4
# 285383 2024-06-19 15:40:56           rub  1319.43              4
#
#         days_since_prev  event_id        service_name event_type_main  \
# 11758               0.0    183706       Билеты в руки           театр
# 11759               0.0    183706       Билеты в руки           театр
# 12677               0.0    553623  Билеты без проблем          другое
# 12678               0.0    553623  Билеты без проблем          другое
# 26868              11.0    393430         Лови билет!        концерты
# ...                 ...       ...                 ...             ...
# 285379              0.0    489843  Билеты без проблем           театр
# 285388              0.0    489843  Билеты без проблем           театр
# 285375              0.0    489843  Билеты без проблем           театр
# 285382              0.0    489843  Билеты без проблем           театр
# 285383              0.0    489843  Билеты без проблем           театр
#
#                  region_name   city_name
# 11758   Светополянский округ   Глиноград
# 11759   Светополянский округ   Глиноград
# 12677     Каменевский регион  Глиногорск
# 12678     Каменевский регион  Глиногорск
# 26868     Каменевский регион  Глиногорск
# ...                      ...         ...
# 285379    Каменевский регион  Глиногорск
# 285388    Каменевский регион  Глиногорск
# 285375    Каменевский регион  Глиногорск
# 285382    Каменевский регион  Глиногорск
# 285383    Каменевский регион  Глиногорск
#
# [93 rows x 14 columns]

# %%
df.duplicated(subset=['user_id', 'order_ts', 'revenue', 'event_id'], keep='first').sum()
# Out:
# np.int64(48)

# %% [markdown]
# Обнаружено 48 записей дубликатов (не считая дубликатами первые найденные записи). В дальнейшем эти дубликаты необходимо удалить.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Дубликаты проверены - молодец, что проверяешь дубликаты также по `order_id` и группе признаков.

# %% [markdown]
# Проверим данные в числовых столбцах на аномалии и выбросы:

# %%
df['tickets_count'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.999])
# Out:
# count    290611.000000
# mean          2.754311
# std           1.170620
# min           1.000000
# 1%            1.000000
# 5%            1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# 95%           5.000000
# 97%           5.000000
# 99.9%         6.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['tickets_count'], vert=False)
plt.title('Boxplot - диаграмма для колонки tickets_count - "Количество купленных билетов"')
plt.xticks(range(df['tickets_count'].min(), df['tickets_count'].max() + 1, 1))
plt.xlabel('Количество купленных билетов (tickets_count)')
plt.show()

# %%
df['tickets_count'].value_counts()
# Out:
# tickets_count
# 3     92247
# 2     83807
# 4     54812
# 1     41798
# 5     13476
# 6      4283
# 7        62
# 9        38
# 8        21
# 10       19
# 11       13
# 13        7
# 17        6
# 19        5
# 12        4
# 14        4
# 15        2
# 27        2
# 30        2
# 47        1
# 57        1
# 37        1
# Name: count, dtype: int64

# %%
df[df['tickets_count'] > 11].sort_values(by='tickets_count')
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 33052   110125b4a429b43                mobile   8056317 2024-10-23
# 55602   23e813ef3cc7702                mobile   1916698 2024-10-24
# 97079   4678b687aef94db                mobile   2950316 2024-09-05
# 228903  c37aeb5b39ffcca               desktop    884646 2024-09-30
# 38928   18e9aead0a393e7               desktop   6751607 2024-08-27
# 127063  6191b67aadb9231               desktop   7298518 2024-10-15
# 33238   1118cc4889189db                mobile   6919082 2024-10-23
# 22182   0beb8fc0c0a9ce1               desktop   7486960 2024-10-08
# 133595  6a71629032a8560                mobile   8591309 2024-08-28
# 211649  b10463dc57814d9                mobile   2291233 2024-10-29
# 29936   0f917cf4c96d1d7                mobile   4343070 2024-06-01
# 31768   104b3035f811116                mobile   7917030 2024-09-18
# 151448  7d22e22c99ec66e               desktop    123628 2024-10-16
# 212424  b1170dcea2e6685                mobile   7814544 2024-10-09
# 31032   1021a86d7ee6fb8                mobile   2965019 2024-09-20
# 46780   1c2a2133e1df1b4                mobile   5247609 2024-09-23
# 22178   0beb8fc0c0a9ce1               desktop   7487018 2024-10-08
# 153323  7eb4fc207ecc10f               desktop    806114 2024-07-19
# 153316  7eb4fc207ecc10f               desktop    806288 2024-07-19
# 154191  7eb4fc207ecc10f               desktop   3526604 2024-08-29
# 153318  7eb4fc207ecc10f               desktop    806230 2024-07-19
# 142917  76694a971889caa               desktop   1427845 2024-10-18
# 278916  f6af1139a64d911                mobile   8188789 2024-10-31
# 190445  9e4f3ad398e1a2e               desktop   3091430 2024-10-15
# 154189  7eb4fc207ecc10f               desktop   3526546 2024-08-29
# 278870  f6af1139a64d911                mobile   8188499 2024-09-11
# 153317  7eb4fc207ecc10f               desktop    806259 2024-07-19
# 153321  7eb4fc207ecc10f               desktop    806143 2024-07-19
# 86247   3ee7dc2e115847f               desktop   5190682 2024-10-06
# 86246   3ee7dc2e115847f               desktop   5190653 2024-10-06
# 154188  7eb4fc207ecc10f               desktop   3526575 2024-08-29
# 154187  7eb4fc207ecc10f               desktop   3526633 2024-08-29
# 154591  7eb4fc207ecc10f               desktop   8151843 2024-09-17
# 39416   18e9aead0a393e7               desktop   5338292 2024-09-09
# 154015  7eb4fc207ecc10f               desktop   3526517 2024-08-22
#
#                   order_ts currency_code  revenue  tickets_count  \
# 33052  2024-10-23 13:49:54           rub  1708.36             12
# 55602  2024-10-24 21:09:23           rub  9954.66             12
# 97079  2024-09-05 19:50:15           rub  1504.63             12
# 228903 2024-09-30 13:56:52           rub   710.19             12
# 38928  2024-08-27 16:02:00           rub  1630.01             13
# 127063 2024-10-15 21:14:02           rub  1630.01             13
# 33238  2024-10-23 21:45:06           rub   978.03             13
# 22182  2024-10-08 14:35:20           rub  1630.01             13
# 133595 2024-08-28 18:42:27           rub  1630.01             13
# 211649 2024-10-29 10:26:44           rub  1800.31             13
# 29936  2024-06-01 15:14:41           rub   155.51             13
# 31768  2024-09-18 10:19:06           rub  1755.40             14
# 151448 2024-10-16 10:10:33           rub   554.72             14
# 212424 2024-10-09 09:12:17           rub  1658.22             14
# 31032  2024-09-20 21:02:58           rub  1155.51             14
# 46780  2024-09-23 11:27:31           rub  1880.78             15
# 22178  2024-10-08 14:32:50           rub  1880.78             15
# 153323 2024-07-19 16:51:50           rub  1723.90             17
# 153316 2024-07-19 16:34:49           rub  1723.90             17
# 154191 2024-08-29 12:57:45           rub     0.00             17
# 153318 2024-07-19 17:21:09           rub  1723.90             17
# 142917 2024-10-18 09:59:15           rub   179.64             17
# 278916 2024-10-31 14:02:29           rub     0.00             17
# 190445 2024-10-15 14:33:21           rub   190.06             19
# 154189 2024-08-29 12:55:06           rub     0.00             19
# 278870 2024-09-11 19:28:17           rub   299.02             19
# 153317 2024-07-19 17:06:30           rub  1926.71             19
# 153321 2024-07-19 17:13:59           rub  1926.71             19
# 86247  2024-10-06 13:08:42           rub   328.49             27
# 86246  2024-10-06 13:06:40           rub   328.49             27
# 154188 2024-08-29 13:01:35           rub     0.00             30
# 154187 2024-08-29 13:03:47           rub     0.00             30
# 154591 2024-09-17 15:41:39           rub  1147.67             37
# 39416  2024-09-09 10:03:45           rub   640.41             47
# 154015 2024-08-22 11:23:50           rub     0.00             57
#
#         days_since_prev  event_id        service_name event_type_main  \
# 33052               0.0    586847           Мой билет          другое
# 55602               NaN    574396     Шоу начинается!        концерты
# 97079               2.0    529629  Билеты без проблем          другое
# 228903              0.0    441168           Мой билет          другое
# 38928               0.0    529629  Билеты без проблем          другое
# 127063              0.0    529629  Билеты без проблем          другое
# 33238               NaN    587223           Мой билет          другое
# 22182               0.0    529629  Билеты без проблем          другое
# 133595              3.0    529629  Билеты без проблем          другое
# 211649              0.0    247998  Билеты без проблем           театр
# 29936               NaN    501198       Билеты в руки          другое
# 31768               0.0    529629  Билеты без проблем          другое
# 151448              0.0    242047       Лучшие билеты           театр
# 212424              0.0    574066  Билеты без проблем          другое
# 31032               0.0    187852       Лучшие билеты          другое
# 46780               0.0    529629  Билеты без проблем          другое
# 22178               1.0    529629  Билеты без проблем          другое
# 153323              0.0    516731           Мой билет           театр
# 153316              0.0    516731           Мой билет           театр
# 154191              0.0    557574  Билеты без проблем          другое
# 153318              0.0    516731           Мой билет           театр
# 142917              5.0    542512  Билеты без проблем          другое
# 278916              0.0    563139         Лови билет!          другое
# 190445              1.0    573817  Билеты без проблем           спорт
# 154189              0.0    557574  Билеты без проблем          другое
# 278870              0.0    542587  Билеты без проблем          другое
# 153317              0.0    516731           Мой билет           театр
# 153321              0.0    516731           Мой билет           театр
# 86247               0.0    575780         Лови билет!           спорт
# 86246               0.0    575780         Лови билет!           спорт
# 154188              0.0    215381  Билеты без проблем          другое
# 154187              0.0    215381  Билеты без проблем          другое
# 154591              0.0    564789       Билеты в руки           спорт
# 39416               0.0    561027  Билеты без проблем           спорт
# 154015              0.0    557574  Билеты без проблем          другое
#
#                  region_name      city_name
# 33052   Североярская область         Озёрск
# 55602     Каменевский регион     Глиногорск
# 97079   Североярская область         Озёрск
# 228903    Каменевский регион     Глиногорск
# 38928   Североярская область         Озёрск
# 127063  Североярская область         Озёрск
# 33238   Североярская область         Озёрск
# 22182   Североярская область         Озёрск
# 133595  Североярская область         Озёрск
# 211649    Каменевский регион     Глиногорск
# 29936       Заречная область   Дальнесветин
# 31768   Североярская область         Озёрск
# 151448      Поленовский край  Дальнозолотск
# 212424  Североярская область         Озёрск
# 31032   Североярская область         Озёрск
# 46780   Североярская область         Озёрск
# 22178   Североярская область         Озёрск
# 153323    Каменевский регион     Глиногорск
# 153316    Каменевский регион     Глиногорск
# 154191    Каменевский регион     Глиногорск
# 153318    Каменевский регион     Глиногорск
# 142917      Речицкая область      Радужанов
# 278916      Лесостепной край     Крутовинск
# 190445  Чистогорская область       Леснойск
# 154189    Каменевский регион     Глиногорск
# 278870      Речицкая область      Радужанов
# 153317    Каменевский регион     Глиногорск
# 153321    Каменевский регион     Глиногорск
# 86247       Озернинский край       Лесоярич
# 86246       Озернинский край       Лесоярич
# 154188    Каменевский регион     Глиногорск
# 154187    Каменевский регион     Глиногорск
# 154591     Медовская область      Радужсвет
# 39416   Чистогорская область       Леснойск
# 154015    Каменевский регион     Глиногорск

# %%
plt.figure(figsize=(15, 5))
plt.hist(df['tickets_count'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки tickets_count - "Количество купленных билетов"')
plt.xticks(range(0, 60, 3))
plt.xlabel('Количество купленных билетов (tickets_count)')
plt.ylabel('Количество заказов')
plt.show()

# %%
df['revenue'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    290611.000000
# mean        625.584360
# std        1227.693064
# min         -90.760000
# 1%            0.000000
# 5%           16.980000
# 25%         116.850000
# 50%         356.010000
# 75%         810.130000
# 95%        1744.990000
# 97%        2094.180000
# 99%        4003.133000
# 99.5%      7397.660000
# 99.9%     17230.320000
# max       81174.540000
# Name: revenue, dtype: float64

# %%
df[df['revenue'] < 0]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 252     00eb3dc9baa1543                mobile   1594653 2024-06-29
# 4522    02ea4583333f064                mobile   2360920 2024-09-03
# 4549    02ea4583333f064                mobile   2361094 2024-09-04
# 8133    043f669c9f734b1                mobile    166809 2024-09-27
# 8134    043f669c9f734b1                mobile    166780 2024-09-27
# ...                 ...                   ...       ...        ...
# 288855  fe237d2cfd6e503                mobile   3700575 2024-10-12
# 288903  fe237d2cfd6e503               desktop   3523646 2024-10-15
# 288904  fe237d2cfd6e503               desktop   3523617 2024-10-15
# 289052  fe237d2cfd6e503                mobile   5445853 2024-10-21
# 290059  ff20aac2834373f                mobile   5114789 2024-10-24
#
#                   order_ts currency_code  revenue  tickets_count  \
# 252    2024-06-29 15:01:43           rub    -2.37              3
# 4522   2024-09-03 18:12:58           rub    -0.23              3
# 4549   2024-09-04 09:34:53           rub    -0.15              2
# 8133   2024-09-27 10:56:35           rub    -0.62              1
# 8134   2024-09-27 10:00:09           rub    -1.86              3
# ...                    ...           ...      ...            ...
# 288855 2024-10-12 08:11:33           rub    -5.70              1
# 288903 2024-10-15 20:32:18           rub    -1.43              3
# 288904 2024-10-15 20:13:13           rub    -0.96              2
# 289052 2024-10-21 20:22:29           rub    -0.61              1
# 290059 2024-10-24 14:05:18           rub    -0.23              3
#
#         days_since_prev  event_id        service_name event_type_main  \
# 252                 NaN    538650  Билеты без проблем          другое
# 4522                0.0    559772  Билеты без проблем          другое
# 4549                0.0    559772  Билеты без проблем          другое
# 8133                1.0    567183       Лучшие билеты          другое
# 8134                0.0    567183       Лучшие билеты          другое
# ...                 ...       ...                 ...             ...
# 288855              0.0    247058         Тебе билет!        концерты
# 288903              0.0    243963       Лучшие билеты          другое
# 288904              0.0    243963       Лучшие билеты          другое
# 289052              0.0    243393       Лучшие билеты          другое
# 290059              6.0    575628       Лучшие билеты          другое
#
#                   region_name    city_name
# 252       Берёзовская область  Златопольск
# 4522      Широковская область  Лесореченск
# 4549      Широковская область  Лесореченск
# 8133    Золотоключевской край    Луговинец
# 8134    Золотоключевской край    Луговинец
# ...                       ...          ...
# 288855       Речицкая область    Радужанов
# 288903   Ягодиновская область    Речинцево
# 288904   Ягодиновская область    Речинцево
# 289052   Ягодиновская область    Речинцево
# 290059  Золотоключевской край  Поляногорье
#
# [381 rows x 14 columns]

# %%
df[df['revenue'] == 0]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 24      0018ecd8a38a51b                mobile   3253250 2024-07-25
# 65      0033403583a55ed                mobile   4130500 2024-06-19
# 66      0033403583a55ed                mobile   4130529 2024-06-19
# 67      0033403583a55ed                mobile   4130442 2024-06-19
# 68      0033403583a55ed                mobile   4130471 2024-06-19
# ...                 ...                   ...       ...        ...
# 290144  ff431fb03dba1e6                mobile   3262211 2024-08-07
# 290238  ff684621b134cc4               desktop   5434427 2024-06-09
# 290375  ff9310a90294d5c                mobile    388514 2024-07-30
# 290376  ff9310a90294d5c                mobile    388485 2024-07-30
# 290472  ffb51f6745ee8a2                mobile   5457656 2024-09-07
#
#                   order_ts currency_code  revenue  tickets_count  \
# 24     2024-07-25 20:38:57           rub      0.0              3
# 65     2024-06-19 11:07:15           rub      0.0              1
# 66     2024-06-19 10:53:29           rub      0.0              1
# 67     2024-06-19 14:57:25           rub      0.0              1
# 68     2024-06-19 11:06:10           rub      0.0              1
# ...                    ...           ...      ...            ...
# 290144 2024-08-07 12:46:13           rub      0.0              4
# 290238 2024-06-09 12:35:52           rub      0.0              3
# 290375 2024-07-30 17:16:52           rub      0.0              3
# 290376 2024-07-30 17:15:36           rub      0.0              3
# 290472 2024-09-07 18:29:13           rub      0.0              1
#
#         days_since_prev  event_id        service_name event_type_main  \
# 24                  NaN    548041  Билеты без проблем           спорт
# 65                  NaN    538926  Билеты без проблем          другое
# 66                  0.0    538926  Билеты без проблем          другое
# 67                  0.0    538926  Билеты без проблем          другое
# 68                  0.0    538926  Билеты без проблем          другое
# ...                 ...       ...                 ...             ...
# 290144              0.0    555672  Билеты без проблем        концерты
# 290238              1.0    524592       Лучшие билеты          другое
# 290375              6.0    553825         Лови билет!           спорт
# 290376              0.0    553825         Лови билет!           спорт
# 290472             66.0    562180  Билеты без проблем          другое
#
#                  region_name   city_name
# 24         Медовская область   Радужсвет
# 65        Каменевский регион  Глиногорск
# 66        Каменевский регион  Глиногорск
# 67        Каменевский регион  Глиногорск
# 68        Каменевский регион  Глиногорск
# ...                      ...         ...
# 290144    Каменевский регион  Глиногорск
# 290238  Североярская область      Озёрск
# 290375    Каменевский регион  Глиногорск
# 290376    Каменевский регион  Глиногорск
# 290472      Шанырский регион   Синеводск
#
# [5526 rows x 14 columns]

# %%
revenue_995 = df['revenue'].quantile(0.995)
df[(df['revenue'] >= revenue_995)]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 277     00f4f5244501ce6                mobile    720419 2024-06-11
# 460     01370a0e9c1a7d5                mobile   2229811 2024-06-04
# 461     01370a0e9c1a7d5                mobile   2229724 2024-06-04
# 464     01370a0e9c1a7d5               desktop   5227657 2024-06-04
# 809     019fa401ddb00aa                mobile   4451269 2024-06-11
# ...                 ...                   ...       ...        ...
# 289650  fe936ae193261e0                mobile   2043341 2024-06-14
# 289651  fe936ae193261e0                mobile   2043283 2024-06-14
# 290058  ff20aac2834373f                mobile   4350755 2024-10-18
# 290077  ff3c5654070575e                mobile   1034228 2024-06-07
# 290217  ff6323d5c9e62ba                mobile   3245942 2024-06-12
#
#                   order_ts currency_code   revenue  tickets_count  \
# 277    2024-06-11 20:15:57           kzt  22021.55              5
# 460    2024-06-04 13:19:47           kzt   7397.66              4
# 461    2024-06-04 13:25:28           kzt   7397.66              4
# 464    2024-06-04 13:28:17           kzt   7397.66              4
# 809    2024-06-11 12:33:38           kzt  22021.55              5
# ...                    ...           ...       ...            ...
# 289650 2024-06-14 16:13:04           kzt  17617.24              4
# 289651 2024-06-14 17:07:20           kzt  13212.93              3
# 290058 2024-10-18 14:52:42           kzt   9471.05              4
# 290077 2024-06-07 19:03:48           kzt   7397.66              4
# 290217 2024-06-12 22:25:39           kzt  13212.93              3
#
#         days_since_prev  event_id        service_name event_type_main  \
# 277                 NaN    536826           Мой билет        концерты
# 460                 1.0    533803           Мой билет        концерты
# 461                 0.0    533803           Мой билет        концерты
# 464                 0.0    533803           Мой билет        концерты
# 809                 2.0    536826           Мой билет        концерты
# ...                 ...       ...                 ...             ...
# 289650              0.0    536826           Мой билет        концерты
# 289651              0.0    536826           Мой билет        концерты
# 290058             34.0    538828  Билеты без проблем        концерты
# 290077              1.0    533803           Мой билет        концерты
# 290217              NaN    536826           Мой билет        концерты
#
#                 region_name   city_name
# 277     Верхоречная область  Серебрянка
# 460        Шанырский регион   Широковка
# 461        Шанырский регион   Широковка
# 464        Шанырский регион   Широковка
# 809     Верхоречная область  Серебрянка
# ...                     ...         ...
# 289650  Верхоречная область  Серебрянка
# 289651  Верхоречная область  Серебрянка
# 290058  Верхоречная область  Серебрянка
# 290077     Шанырский регион   Широковка
# 290217  Верхоречная область  Серебрянка
#
# [1458 rows x 14 columns]

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue)')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue)')
plt.xlim(df['revenue'].min()-100, 1000)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue)')
plt.xlim(0, 7500)
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(df['revenue'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки revenue - "Выручка от заказа"')
#plt.xticks(range(-5000, 85000, 5000))
plt.xlabel('Выручка от заказа (revenue)')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# Общие выводы по итогам загрузки данных Яндекс Афиши:
#
# - **Размер данных:** 290611 строк и 14 столбцов, занимаемый объем - 31 Мб
# - **Качество данных:** данные соответствуют описанию, названия колонок соответствуют содержимому.
# - **Особенности пропусков:** не большое количество нулевых значений наблюдается в колонке days_since_prev (7.5%), пропуски объяснимы тем, что у пользователей может быть один (первый) заказ (нет предыдущего заказа).
# - **Колонка `days_since_prev`:** данные можно преобразовать в целочисленный тип с возможностью NaN значений(`Int32`).
# - **Колонки `order_id`, `event_id`:** данные можно преобразовать в целочисленный тип с возможностью NaN значений(`Int32`).
# - **Колонка `tickets_count`:** данные можно преобразовать в беззнаковый целый тип с малой размерностью (`UInt8`).
# - **Колонка `revenue`:** не меняем тип данных для сохранения точности значений.
# - **Категориальные данные**: явных или неявных дубликатов или аномальных значений в категориальных данных не обнаружено
# - **Дубликаты**: полных явных дубликатов не обнаружено, обнаружены явные дубликаты по набору колонок user_id, order_ts, revenue_rub, event_id - 48 записей - их будем вычищать.
# - **Аномалии и выбросы**
#  - колонка `tickets_count`: аномальных значений не выявлено, на распределении присутствует очень тонкий и сужающийся правый хвост - крупные заказы (например, групповые) - который можно исключить из анализа по перцентилю 99.9 (ввиду статистически малого количества значений выше перецентиля 99.9).
#  - колонка `revenue`: присутствуют аномальные значения (0 - возможно покупки по акции, отрицательные значения - возможно возвраты билетов) - аномальные значения для анализа возможно исключить, на распределении присутствует длинный тяжелый правый хвост, который можно исключить из анализа по перцентилю 99.5

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Первичный анализ данных выполнен, намечены шаги по их обработке.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведем выручку к единой валюте — российскому рублю.
#
# Для этого используем датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`, расположенный в сети по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# **Второй источник данных** - CSV-файл с курсами казахского теньге (KZT) к российскому рублю (RUB) за 2024 год (значения в рублях представлены для 100 тенге).
#
# Результаты преобразования сохраним в новый столбец `revenue_rub`.

# %%
df_conversion = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %%
df_conversion.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
df_conversion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %% [markdown]
# Приведем тип данных в колонке `data` в типу `datetime64[ns]`

# %%
df_conversion['data'] = pd.to_datetime(df_conversion['data'])

# %%
df_conversion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    datetime64[ns]
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 11.3+ KB

# %% [markdown]
# Объединим датасет Яедекс Афиши с датасетом курса тенге

# %%
count_before_joining = df.shape[0]

# %%
df = df.merge(df_conversion, how='left', left_on='order_dt', right_on='data')

# %% [markdown]
# Удалим лишние колонки, появившиеся при объединении

# %%
df = df.drop(columns=['data', 'nominal', 'cdx'])

# %% [markdown]
# Проверим результат объединения датасетов

# %%
df.head(10)
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
# 5  000898990054619                mobile   2613713 2024-10-23
# 6  00096d1f542ab2b               desktop   6636941 2024-08-15
# 7  000a55a418c128c                mobile   4657981 2024-09-29
# 8  000a55a418c128c                mobile   4657952 2024-10-15
# 9  000cf0659a9f40f                mobile   6818191 2024-06-20
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
# 5 2024-10-23 15:12:00           rub   902.74              3             19.0
# 6 2024-08-15 16:48:48           rub   917.83              4              NaN
# 7 2024-09-29 19:39:12           rub    47.78              1              NaN
# 8 2024-10-15 10:29:04           rub    74.84              2             16.0
# 9 2024-06-20 10:51:10           rub  1421.91              4              NaN
#
#    event_id        service_name event_type_main           region_name  \
# 0    169230        Край билетов           театр    Каменевский регион
# 1    237325           Мой билет        выставки    Каменевский регион
# 2    578454         За билетом!          другое    Каменевский регион
# 3    387271         Лови билет!          другое  Североярская область
# 4    509453  Билеты без проблем         стендап      Озернинский край
# 5    500862             Облачко        концерты  Лугоградская область
# 6    201953        Край билетов           театр    Каменевский регион
# 7    265857       Лучшие билеты           театр      Поленовский край
# 8    271579       Лучшие билеты           театр      Поленовский край
# 9    516728         Лови билет!        концерты   Широковская область
#
#        city_name     curs
# 0     Глиногорск  18.6972
# 1     Глиногорск  18.3419
# 2     Глиногорск  19.6475
# 3         Озёрск  18.5010
# 4    Родниковецк  19.6648
# 5    Кристалевск  20.0531
# 6     Глиногорск  18.7730
# 7  Дальнозолотск  19.3741
# 8  Дальнозолотск  19.7185
# 9   Радужнополье  18.0419

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  service_name           290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  region_name            290611 non-null  object
#  13  city_name              290611 non-null  object
#  14  curs                   290611 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 33.3+ MB

# %% [markdown]
# Проверим неизменность размера датасета (избыточная проверка при left-join'е, но лучше быть бдительным всегда)

# %%
df.shape[0] - count_before_joining
# Out:
# 0

# %% [markdown]
# Сохраним количество строк а датасете до преобразований

# %%
count_before_transforming = df.shape[0]

# %%
df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)

# %% [markdown]
# Колонка с курсом нам более не понадобится, удаляем

# %%
df = df.drop(columns=['curs'])

# %%
df.shape[0] - count_before_transforming
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  service_name           290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  region_name            290611 non-null  object
#  13  city_name              290611 non-null  object
#  14  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 33.3+ MB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выручка приведена к единой валюте.

# %% [markdown]
# **Проверим данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  service_name           290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  region_name            290611 non-null  object
#  13  city_name              290611 non-null  object
#  14  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 33.3+ MB

# %% [markdown]
# Еще раз сохраним контрольную точку - количество записей в датасете

# %%
count_before_transforming = df.shape[0]

# %% [markdown]
# Пропуски в датасете только в колонке `days_since_prev`, выгрузка данных успешна.

# %% [markdown]
# **Преобразуем типы данных в некоторых столбцах, если это необходимо. Обратим внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.**

# %% [markdown]
# Приведем столбец `days_since_prev` к целочисленному типу данных с возможностью хранить NaN значения

# %%
df['days_since_prev'] = df['days_since_prev'].astype('Int32')

# %% [markdown]
# Округлим значения в колонках выручки `revenue`, `revenue_rub` до 2 знаков. Тип данных сохраним, чтобы избежать потери точности данных.

# %%
df['revenue'] = df['revenue'].round(2)
df['revenue_rub'] = df['revenue_rub'].round(2)

# %% [markdown]
# Оптимизируем типы данных в колонках `order_id`, `event_id`, `tickets_count`

# %%
df['order_id'] = df['order_id'].astype('int32')
df['event_id'] = df['event_id'].astype('int32')
df['tickets_count'] = df['tickets_count'].astype('uint8')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Типы данных скорректированы.

# %%
df.shape[0] - count_before_transforming
# Out:
# 0

# %% [markdown]
# **Проверим на аномалии и выбросы данные в колонке `revenue_rub`**

# %%
df['revenue_rub'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    290611.000000
# mean        555.571989
# std         875.498170
# min         -90.760000
# 1%            0.000000
# 5%           16.830000
# 25%         113.970000
# 50%         351.140000
# 75%         802.050000
# 95%        1630.650000
# 97%        1945.830000
# 99%        2628.420000
# 99.5%      3145.570000
# 99.9%      5140.780000
# max       81174.540000
# Name: revenue_rub, dtype: float64

# %%
df[df['revenue_rub'] < 0]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 252     00eb3dc9baa1543                mobile   1594653 2024-06-29
# 4522    02ea4583333f064                mobile   2360920 2024-09-03
# 4549    02ea4583333f064                mobile   2361094 2024-09-04
# 8133    043f669c9f734b1                mobile    166809 2024-09-27
# 8134    043f669c9f734b1                mobile    166780 2024-09-27
# ...                 ...                   ...       ...        ...
# 288855  fe237d2cfd6e503                mobile   3700575 2024-10-12
# 288903  fe237d2cfd6e503               desktop   3523646 2024-10-15
# 288904  fe237d2cfd6e503               desktop   3523617 2024-10-15
# 289052  fe237d2cfd6e503                mobile   5445853 2024-10-21
# 290059  ff20aac2834373f                mobile   5114789 2024-10-24
#
#                   order_ts currency_code  revenue  tickets_count  \
# 252    2024-06-29 15:01:43           rub    -2.37              3
# 4522   2024-09-03 18:12:58           rub    -0.23              3
# 4549   2024-09-04 09:34:53           rub    -0.15              2
# 8133   2024-09-27 10:56:35           rub    -0.62              1
# 8134   2024-09-27 10:00:09           rub    -1.86              3
# ...                    ...           ...      ...            ...
# 288855 2024-10-12 08:11:33           rub    -5.70              1
# 288903 2024-10-15 20:32:18           rub    -1.43              3
# 288904 2024-10-15 20:13:13           rub    -0.96              2
# 289052 2024-10-21 20:22:29           rub    -0.61              1
# 290059 2024-10-24 14:05:18           rub    -0.23              3
#
#         days_since_prev  event_id        service_name event_type_main  \
# 252                <NA>    538650  Билеты без проблем          другое
# 4522                  0    559772  Билеты без проблем          другое
# 4549                  0    559772  Билеты без проблем          другое
# 8133                  1    567183       Лучшие билеты          другое
# 8134                  0    567183       Лучшие билеты          другое
# ...                 ...       ...                 ...             ...
# 288855                0    247058         Тебе билет!        концерты
# 288903                0    243963       Лучшие билеты          другое
# 288904                0    243963       Лучшие билеты          другое
# 289052                0    243393       Лучшие билеты          другое
# 290059                6    575628       Лучшие билеты          другое
#
#                   region_name    city_name  revenue_rub
# 252       Берёзовская область  Златопольск        -2.37
# 4522      Широковская область  Лесореченск        -0.23
# 4549      Широковская область  Лесореченск        -0.15
# 8133    Золотоключевской край    Луговинец        -0.62
# 8134    Золотоключевской край    Луговинец        -1.86
# ...                       ...          ...          ...
# 288855       Речицкая область    Радужанов        -5.70
# 288903   Ягодиновская область    Речинцево        -1.43
# 288904   Ягодиновская область    Речинцево        -0.96
# 289052   Ягодиновская область    Речинцево        -0.61
# 290059  Золотоключевской край  Поляногорье        -0.23
#
# [381 rows x 15 columns]

# %%
df[df['revenue_rub'] == 0]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 24      0018ecd8a38a51b                mobile   3253250 2024-07-25
# 65      0033403583a55ed                mobile   4130500 2024-06-19
# 66      0033403583a55ed                mobile   4130529 2024-06-19
# 67      0033403583a55ed                mobile   4130442 2024-06-19
# 68      0033403583a55ed                mobile   4130471 2024-06-19
# ...                 ...                   ...       ...        ...
# 290144  ff431fb03dba1e6                mobile   3262211 2024-08-07
# 290238  ff684621b134cc4               desktop   5434427 2024-06-09
# 290375  ff9310a90294d5c                mobile    388514 2024-07-30
# 290376  ff9310a90294d5c                mobile    388485 2024-07-30
# 290472  ffb51f6745ee8a2                mobile   5457656 2024-09-07
#
#                   order_ts currency_code  revenue  tickets_count  \
# 24     2024-07-25 20:38:57           rub      0.0              3
# 65     2024-06-19 11:07:15           rub      0.0              1
# 66     2024-06-19 10:53:29           rub      0.0              1
# 67     2024-06-19 14:57:25           rub      0.0              1
# 68     2024-06-19 11:06:10           rub      0.0              1
# ...                    ...           ...      ...            ...
# 290144 2024-08-07 12:46:13           rub      0.0              4
# 290238 2024-06-09 12:35:52           rub      0.0              3
# 290375 2024-07-30 17:16:52           rub      0.0              3
# 290376 2024-07-30 17:15:36           rub      0.0              3
# 290472 2024-09-07 18:29:13           rub      0.0              1
#
#         days_since_prev  event_id        service_name event_type_main  \
# 24                 <NA>    548041  Билеты без проблем           спорт
# 65                 <NA>    538926  Билеты без проблем          другое
# 66                    0    538926  Билеты без проблем          другое
# 67                    0    538926  Билеты без проблем          другое
# 68                    0    538926  Билеты без проблем          другое
# ...                 ...       ...                 ...             ...
# 290144                0    555672  Билеты без проблем        концерты
# 290238                1    524592       Лучшие билеты          другое
# 290375                6    553825         Лови билет!           спорт
# 290376                0    553825         Лови билет!           спорт
# 290472               66    562180  Билеты без проблем          другое
#
#                  region_name   city_name  revenue_rub
# 24         Медовская область   Радужсвет          0.0
# 65        Каменевский регион  Глиногорск          0.0
# 66        Каменевский регион  Глиногорск          0.0
# 67        Каменевский регион  Глиногорск          0.0
# 68        Каменевский регион  Глиногорск          0.0
# ...                      ...         ...          ...
# 290144    Каменевский регион  Глиногорск          0.0
# 290238  Североярская область      Озёрск          0.0
# 290375    Каменевский регион  Глиногорск          0.0
# 290376    Каменевский регион  Глиногорск          0.0
# 290472      Шанырский регион   Синеводск          0.0
#
# [5526 rows x 15 columns]

# %%
revenue_995 = df['revenue_rub'].quantile(0.995)
df[(df['revenue_rub'] >= revenue_995)]
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 277     00f4f5244501ce6                mobile    720419 2024-06-11
# 441     011becee63d8a50                mobile   8447643 2024-08-09
# 621     013f1a7c3088caa               desktop   5148429 2024-07-13
# 713     0186f6e000b581c                mobile   7047610 2024-09-14
# 716     0186f6e000b581c                mobile   7047784 2024-09-14
# ...                 ...                   ...       ...        ...
# 288628  fe237d2cfd6e503                mobile    949606 2024-10-02
# 289649  fe936ae193261e0                mobile   2043312 2024-06-14
# 289650  fe936ae193261e0                mobile   2043341 2024-06-14
# 290102  ff3c5654070575e               desktop   2600982 2024-09-03
# 290105  ff3c5654070575e               desktop   2600924 2024-09-04
#
#                   order_ts currency_code   revenue  tickets_count  \
# 277    2024-06-11 20:15:57           kzt  22021.55              5
# 441    2024-08-09 16:07:47           rub   3632.00              4
# 621    2024-07-13 17:01:47           rub   3239.48              3
# 713    2024-09-14 07:28:38           rub   3336.21              5
# 716    2024-09-14 07:22:49           rub   3336.21              5
# ...                    ...           ...       ...            ...
# 288628 2024-10-02 22:10:05           rub  16234.91              1
# 289649 2024-06-14 15:57:09           kzt  17617.24              4
# 289650 2024-06-14 16:13:04           kzt  17617.24              4
# 290102 2024-09-03 07:08:57           rub   4533.91              4
# 290105 2024-09-04 08:03:18           rub   4533.91              4
#
#         days_since_prev  event_id        service_name event_type_main  \
# 277                <NA>    536826           Мой билет        концерты
# 441                  24    547262  Билеты без проблем        концерты
# 621                <NA>    534849           Мой билет        концерты
# 713                   0    402680      Весь в билетах        концерты
# 716                   0    402680      Весь в билетах        концерты
# ...                 ...       ...                 ...             ...
# 288628                0    552398             Облачко        концерты
# 289649                0    536826           Мой билет        концерты
# 289650                0    536826           Мой билет        концерты
# 290102                2    467322         Show_ticket           театр
# 290105                1    467322         Show_ticket           театр
#
#                  region_name   city_name  revenue_rub
# 277      Верхоречная область  Серебрянка      4380.70
# 441       Каменевский регион  Глиногорск      3632.00
# 621     Горицветская область   Островецк      3239.48
# 713     Малиновоярский округ   Верховино      3336.21
# 716     Малиновоярский округ   Верховино      3336.21
# ...                      ...         ...          ...
# 288628  Североярская область      Озёрск     16234.91
# 289649   Верхоречная область  Серебрянка      3439.77
# 289650   Верхоречная область  Серебрянка      3439.77
# 290102    Каменевский регион  Глиногорск      4533.91
# 290105    Каменевский регион  Глиногорск      4533.91
#
# [1456 rows x 15 columns]

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue_rub'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue_rub - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue_rub'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue_rub - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.xlim(df['revenue_rub'].min()-100, 1000)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(df['revenue_rub'], vert=False)
plt.title('Boxplot - диаграмма для колонки revenue_rub - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.xlim(0, 7500)
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(df['revenue_rub'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки revenue_rub - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# Сохраним значение контрольного показателя - количества строк в датасете

# %%
count_before_transforming = df.shape[0]

# %% [markdown]
# В колонке `revenue_rub` удалим данные с выручкой менее или равной нулю

# %%
df = df[df['revenue_rub'] > 0]

# %%
df['revenue_rub'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    284704.000000
# mean        567.102257
# std         880.828882
# min           0.020000
# 1%            8.160000
# 5%           23.891500
# 25%         124.730000
# 50%         364.280000
# 75%         811.610000
# 95%        1645.200000
# 97%        1952.957600
# 99%        2628.420000
# 99.5%      3164.690000
# 99.9%      5140.780000
# max       81174.540000
# Name: revenue_rub, dtype: float64

# %% [markdown]
# Удалим из датасета записи по 99.9 перецентилю по колонке `tickets_count`

# %%
tickets_count_999 = df['tickets_count'].quantile(0.999)
df = df[(df['tickets_count'] < tickets_count_999)]

# %%
df['tickets_count'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.999])
# Out:
# count    280264.000000
# mean          2.704357
# std           1.081329
# min           1.000000
# 1%            1.000000
# 5%            1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# 95%           4.000000
# 97%           5.000000
# 99.9%         5.000000
# max           5.000000
# Name: tickets_count, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.hist(df['tickets_count'], bins=10, edgecolor='black')
plt.title('Гистограмма для колонки tickets_count - "Количество купленных билетов"')
plt.xticks(range(1, 6, 1))
plt.xlabel('Количество купленных билетов (tickets_count)')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# Удалим из датасета записи по 99.5 перецентилю по колонке `revenue_rub`

# %%
revenue_rub_995 = df['revenue_rub'].quantile(0.995)
df = df[(df['revenue_rub'] < revenue_rub_995)]

# %%
df['revenue_rub'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    278858.000000
# mean        532.509970
# std         524.223943
# min           0.020000
# 1%            8.080000
# 5%           23.350000
# 25%         121.980000
# 50%         357.920000
# 75%         798.870000
# 95%        1577.800000
# 97%        1826.720000
# 99%        2290.810000
# 99.5%      2594.440000
# 99.9%      2843.430000
# max        3044.530000
# Name: revenue_rub, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.hist(df['revenue_rub'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки revenue_rub - "Выручка от заказа"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Численные признаки изучены, удалены выбросы.

# %% [markdown]
# Удалим дубликаты по колонкам `user_id`, `order_ts`, `revenue_rub`, `event_id`

# %%
df = df.drop_duplicates(subset=['user_id', 'order_ts', 'revenue_rub', 'event_id'], keep='first')

# %% [markdown]
# Проверим количество удаленных записей датасета:

# %%
count_del = count_before_transforming - df.shape[0]
print(f"Количество удалённых строк: {count_del}")
prc_del = (count_del / count_before_transforming) * 100
print(f"Процент удалённых строк: {prc_del:.2f}%")
# Out:
# Количество удалённых строк: 11794
# Процент удалённых строк: 4.06%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 278817 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                278817 non-null  object
#  1   device_type_canonical  278817 non-null  object
#  2   order_id               278817 non-null  int32
#  3   order_dt               278817 non-null  datetime64[ns]
#  4   order_ts               278817 non-null  datetime64[ns]
#  5   currency_code          278817 non-null  object
#  6   revenue                278817 non-null  float64
#  7   tickets_count          278817 non-null  uint8
#  8   days_since_prev        257662 non-null  Int32
#  9   event_id               278817 non-null  int32
#  10  service_name           278817 non-null  object
#  11  event_type_main        278817 non-null  object
#  12  region_name            278817 non-null  object
#  13  city_name              278817 non-null  object
#  14  revenue_rub            278817 non-null  float64
# dtypes: Int32(1), datetime64[ns](2), float64(2), int32(2), object(7), uint8(1)
# memory usage: 29.2+ MB

# %% [markdown]
# Итоги шага 2 проекта:
#
# 1. **Объединенили основной датафрейм с датафреймом с курсами казахского тенге**
#
# 2. **Создали новый столбец `revenue_rub`** с выручкой в рублях, приведенной для ранее указанной выручке в казахских тенге по курсу на дату записи.
#
# 3. **Округлили значения числовых столбцов** `curs`, `revenue`, `revenue_rub` до 2 знаков после запятой.
#
# 4. **Оптимизировали типы данных в столбцах** (Обоснование принятой стратегии см. в выводах шага 1 проекта):
#    - `days_since_prev`к тиипу `Int32` (значения всегда целые, приведенный тип данных поддерживает NaN).
#    - `order_id`, `event_id`к типу `int32`.
#    - `tickets_count` к типу `uint8` (беззнаковый целый тип, т к соответствует данным столбца).
#    - `revenue`, `revenue_rub`, `curs` к типу `float64` для сохранения точности.
#
#
# 5. **Удалили лишние столбцы, полученные при объединении датасетов**
#
# 6. **В колонке `revenue_rub` удалили отрицательные и нулевые значения для выравнивания данных для анализа.** Обоснование принятой стратегии см. в выводах шага 1 проекта.
#
# 7. **В колонках `tickets_count` (по 0.999 перцентилю) и `revenue_rub` (по 0.95 перцентилю) удалили записи с выбросами для выравнивания данных для анализа.** Обоснование принятой стратегии см. в выводах шага 1 проекта (для колонки `revenue_rub` на шаге 2 проведена проверка применимости стратегии для сконструированного признака).
#
# 8. **Удалили дубликаты по колонкам `user_id`, `order_ts`, `revenue_rub`, `event_id`** Обоснование принятой стратегии см. в выводах шага 1 проекта.
#
# **Итоги очистки датасета от дубликатов, аномалий и выбросов:**
# * Количество удалённых строк: **11794**
# * Процент удалённых строк: **4.06%**
# * Количество строк до очистки: **290611**
# * Количество строк после очистки: **278817**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные обработаны - молодец, что оцениваешь потери после фильтрации.

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# Построим агрегированные признаки, описывающие поведение и профиль каждого пользователя для отдела маркетинга, который планирует создать модель для прогнозирования возврата пользователей.
#
# Перед тем, как строить профиль, отсортируем данные по времени совершения заказа.
#
# Для каждого пользователя найдем:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используем поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# Добавим два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.

# %% [markdown]
# Перед построением профиля отсортируем данные по времени совершения заказа

# %%
df = df.sort_values(['user_id', 'order_dt'])

# %% [markdown]
# Создадим сводную таблицу профиля пользователя

# %%
user_profile = df.groupby('user_id').agg(
    first_order_dt=('order_dt', 'first'),
    last_order_dt=('order_dt', 'last'),
    first_device=('device_type_canonical', 'first'),
    first_region=('region_name', 'first'),
    first_service=('service_name', 'first'),
    first_event_type=('event_type_main', 'first'),
    total_orders=('order_id', 'count'),
    avg_revenue_rub=('revenue_rub', 'mean'),
    avg_tickets=('tickets_count', 'mean')
).reset_index()

# %% [markdown]
# Сконструируем признак количества дней между заказами пользователя

# %%
#df['days_between_orders'] = df.groupby('user_id')['order_dt'].diff().dt.days

# %%
average_days = df.groupby('user_id')['days_since_prev'].mean()

# %%
#user_profile['days_between_orders'] = df.groupby('user_id')['days_since_prev'].mean()

# %% [markdown]
# ~~Найдем среднее значение по сконструированному признаку количества дней между заказами~~

# %%
#average_days = df.groupby('user_id')['days_between_orders'].mean()

# %% [markdown]
# ~~Добавим среднее значение количества дней между заказами к профилю пользователя~~

# %%
user_profile = user_profile.merge(average_days, on='user_id', how='left')

# %%
user_profile = user_profile.rename(columns={'days_since_prev': 'days_between_orders'})

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Разница между заказами посчитана в `days_since_prev` - пересчитывать её не нужно, так как у заказчика может быть своя методология для оценки показателя.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# Добавим в профиль пользователя сконструированный признак `is_two` — совершил ли пользователь 2 и более заказа

# %%
user_profile['is_two'] = (user_profile['total_orders'] >= 2).astype('uint8')

# %% [markdown]
# Добавим в профиль пользователя сконструированный признак `is_five` — совершил ли пользователь 5 и более заказов

# %%
user_profile['is_five'] = (user_profile['total_orders'] >= 5).astype('uint8')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Профиль пользователя создан.

# %% [markdown]
# Посмотрим на данные в профиле пользователя

# %%
user_profile.head(10)
# Out:
#            user_id first_order_dt last_order_dt first_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
# 2  000898990054619     2024-07-13    2024-10-23       mobile
# 3  00096d1f542ab2b     2024-08-15    2024-08-15      desktop
# 4  000a55a418c128c     2024-09-29    2024-10-15       mobile
# 5  000cf0659a9f40f     2024-06-20    2024-06-21       mobile
# 6  00147c9209d45d3     2024-06-25    2024-06-25       mobile
# 7  00199a573901564     2024-06-17    2024-06-17       mobile
# 8  001e7037d013f0f     2024-07-04    2024-09-29       mobile
# 9  0020c5654c92ec1     2024-07-02    2024-07-02       mobile
#
#            first_region       first_service first_event_type  total_orders  \
# 0    Каменевский регион        Край билетов            театр             1
# 1    Каменевский регион           Мой билет         выставки             2
# 2  Североярская область         Лови билет!           другое             3
# 3    Каменевский регион        Край билетов            театр             1
# 4      Поленовский край       Лучшие билеты            театр             2
# 5   Широковская область         Лови билет!         концерты            13
# 6    Каменевский регион             Облачко         концерты             2
# 7    Каменевский регион  Билеты без проблем         концерты             1
# 8   Златопольский округ           Мой билет           другое             3
# 9    Каменевский регион  Билеты без проблем         концерты             2
#
#    avg_revenue_rub  avg_tickets  days_between_orders  is_two  is_five
# 0      1521.940000     4.000000                 <NA>       0        0
# 1       774.010000     3.000000                 75.0       1        0
# 2       767.213333     2.666667                 51.0       1        0
# 3       917.830000     4.000000                 <NA>       0        0
# 4        61.310000     1.500000                 16.0       1        0
# 5      1175.808462     3.307692             0.083333       1        1
# 6       352.945000     1.500000                  0.0       1        0
# 7       588.120000     4.000000                 <NA>       0        0
# 8       326.623333     1.333333                 43.5       1        0
# 9       193.420000     2.000000                  0.0       1        0

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21588 entries, 0 to 21587
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              21588 non-null  object
#  1   first_order_dt       21588 non-null  datetime64[ns]
#  2   last_order_dt        21588 non-null  datetime64[ns]
#  3   first_device         21588 non-null  object
#  4   first_region         21588 non-null  object
#  5   first_service        21588 non-null  object
#  6   first_event_type     21588 non-null  object
#  7   total_orders         21588 non-null  int64
#  8   avg_revenue_rub      21588 non-null  float64
#  9   avg_tickets          21588 non-null  float64
#  10  days_between_orders  13409 non-null  Float64
#  11  is_two               21588 non-null  uint8
#  12  is_five              21588 non-null  uint8
# dtypes: Float64(1), datetime64[ns](2), float64(2), int64(1), object(5), uint8(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Оптимизируем модель хранения для профиля пользователя:
#
# - `total_orders` - приведем к беззнаковому целому `uint16` ориентируясь на суть данных,
# - `avg_revenue_rub` - приведем к целому `Int64` (копейки можно отбросить для анализа),
# - `avg_tickets` - округлим до 1 знака, т. к. большая точность избыточна для анализа,
# - `days_between_orders` - округлим до 1 знака, т. к. большая точность избыточна для анализа.

# %%
user_profile['total_orders'] = user_profile['total_orders'].astype('uint16')
user_profile['avg_revenue_rub'] = pd.to_numeric(user_profile['avg_revenue_rub'], errors='coerce').round().astype('Int64')
for col in ['avg_tickets', 'days_between_orders']:
    user_profile[col] = user_profile[col].astype('float64').round(1)

# %% [markdown]
# Посмотрим на получившийся в результате датасет:

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21588 entries, 0 to 21587
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              21588 non-null  object
#  1   first_order_dt       21588 non-null  datetime64[ns]
#  2   last_order_dt        21588 non-null  datetime64[ns]
#  3   first_device         21588 non-null  object
#  4   first_region         21588 non-null  object
#  5   first_service        21588 non-null  object
#  6   first_event_type     21588 non-null  object
#  7   total_orders         21588 non-null  uint16
#  8   avg_revenue_rub      21588 non-null  Int64
#  9   avg_tickets          21588 non-null  float64
#  10  days_between_orders  13409 non-null  float64
#  11  is_two               21588 non-null  uint8
#  12  is_five              21588 non-null  uint8
# dtypes: Int64(1), datetime64[ns](2), float64(2), object(5), uint16(1), uint8(2)
# memory usage: 1.8+ MB

# %%
user_profile.head(10)
# Out:
#            user_id first_order_dt last_order_dt first_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
# 2  000898990054619     2024-07-13    2024-10-23       mobile
# 3  00096d1f542ab2b     2024-08-15    2024-08-15      desktop
# 4  000a55a418c128c     2024-09-29    2024-10-15       mobile
# 5  000cf0659a9f40f     2024-06-20    2024-06-21       mobile
# 6  00147c9209d45d3     2024-06-25    2024-06-25       mobile
# 7  00199a573901564     2024-06-17    2024-06-17       mobile
# 8  001e7037d013f0f     2024-07-04    2024-09-29       mobile
# 9  0020c5654c92ec1     2024-07-02    2024-07-02       mobile
#
#            first_region       first_service first_event_type  total_orders  \
# 0    Каменевский регион        Край билетов            театр             1
# 1    Каменевский регион           Мой билет         выставки             2
# 2  Североярская область         Лови билет!           другое             3
# 3    Каменевский регион        Край билетов            театр             1
# 4      Поленовский край       Лучшие билеты            театр             2
# 5   Широковская область         Лови билет!         концерты            13
# 6    Каменевский регион             Облачко         концерты             2
# 7    Каменевский регион  Билеты без проблем         концерты             1
# 8   Златопольский округ           Мой билет           другое             3
# 9    Каменевский регион  Билеты без проблем         концерты             2
#
#    avg_revenue_rub  avg_tickets  days_between_orders  is_two  is_five
# 0             1522          4.0                  NaN       0        0
# 1              774          3.0                 75.0       1        0
# 2              767          2.7                 51.0       1        0
# 3              918          4.0                  NaN       0        0
# 4               61          1.5                 16.0       1        0
# 5             1176          3.3                  0.1       1        1
# 6              353          1.5                  0.0       1        0
# 7              588          4.0                  NaN       0        0
# 8              327          1.3                 43.5       1        0
# 9              193          2.0                  0.0       1        0

# %% [markdown]
# Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными мы работаем: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитаем:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучим статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оценим данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдём аномальные значения, опишем их и примем обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если будем проведить фильтрацию, то вычислим объём отфильтрованных данных и выведем статистические показатели по обновлённому датасету.

# %%
# Общее число пользователей
total_users = len(user_profile)

# Средняя выручка с одного заказа
avg_revenue_per_order = user_profile['avg_revenue_rub'].mean()

# Доля пользователей с 2 и более заказами
is_two_or_more = (user_profile['is_two'] == 1).mean()

# Доля пользователей с 5 и более заказами
is_five_or_more = (user_profile['is_five'] == 1).mean()

# Выводим результаты
print(f"Общее число пользователей: {total_users}")
print(f"Средняя выручка с одного заказа: {avg_revenue_per_order:.2f} руб.")
print(f"Доля пользователей с 2 и более заказами: {is_two_or_more:.2%}")
print(f"Доля пользователей с 5 и более заказами: {is_five_or_more:.2%}")
# Out:
# Общее число пользователей: 21588
# Средняя выручка с одного заказа: 554.74 руб.
# Доля пользователей с 2 и более заказами: 61.65%
# Доля пользователей с 5 и более заказами: 28.83%

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично, что используешь `mean` для оценки долей.

# %%
user_profile['total_orders'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    21588.000000
# mean        12.915370
# std        118.481781
# min          1.000000
# 1%           1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# 95%         31.000000
# 97%         53.000000
# 99%        149.130000
# 99.5%      317.520000
# 99.9%     1434.543000
# max       9816.000000
# Name: total_orders, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(user_profile['total_orders'], vert=False)
plt.title('Boxplot - диаграмма для колонки профиля пользователя total_orders - "Общее количество заказов"')
plt.xlabel('Выручка от заказа (revenue_rub)')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(user_profile['total_orders'], vert=False)
plt.title('Boxplot - диаграмма для колонки профиля пользователя total_orders - "Общее количество заказов"')
plt.xlim(0, 100)
plt.xticks(range(0, 101, 5))
plt.xlabel('Общее количество заказов (total_orders)')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(user_profile['total_orders'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки профиля пользователя total_orders - "Общее количество заказов"')
plt.xlabel('Общее количество заказов (total_orders)')
plt.ylabel('Частота')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(user_profile['total_orders'], bins=3000, edgecolor='black')
plt.title('Гистограмма для колонки профиля пользователя total_orders - "Общее количество заказов"')
plt.xlim(0, 100)
plt.xticks(range(0, 101, 5))
plt.xlabel('Общее количество заказов (total_orders)')
plt.ylabel('Частота')
plt.show()

# %%
user_profile['total_orders'].value_counts().sort_index()
# Out:
# total_orders
# 1       8279
# 2       3554
# 3       2146
# 4       1385
# 5        960
#         ...
# 3542       1
# 3661       1
# 3842       1
# 4230       1
# 9816       1
# Name: count, Length: 329, dtype: int64

# %% [markdown]
# - Объем данных по колонке `total_orders` достаточен для анализа.
# - Исходя из картины распределения данных колонки `total_orders` (плотность популяции в области выбросов) будем фильтровать выбросы по 99 перцентилю (правее единичные выбросы, которыми можно пожертвовать без искажения картины)

# %%
user_profile['avg_tickets'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    21588.000000
# mean         2.703196
# std          0.854780
# min          1.000000
# 1%           1.000000
# 5%           1.000000
# 25%          2.000000
# 50%          2.700000
# 75%          3.000000
# 95%          4.000000
# 97%          4.300000
# 99%          5.000000
# 99.5%        5.000000
# 99.9%        5.000000
# max          5.000000
# Name: avg_tickets, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(user_profile['avg_tickets'], vert=False)
plt.title('Boxplot - диаграмма для колонки профиля пользователя avg_tickets - "Среднее количество билетов"')
plt.xlabel('Среднее количество билетов (avg_tickets)')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(user_profile['avg_tickets'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки профиля пользователя avg_tickets - "Среднее количество билетов"')
plt.xlabel('Среднее количество билетов (avg_tickets)')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# - Объем данных по колонке `avg_tickets` достаточен для анализа.
# - В принципе выбросы по клонке `avg_tickets` практически отсутствуют (ранее уже фильтровали по количеству билетов), так что чистить не требуется.

# %%
user_profile['days_between_orders'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    13409.000000
# mean        15.833082
# std         22.290192
# min          0.000000
# 1%           0.000000
# 5%           0.000000
# 25%          1.000000
# 50%          8.000000
# 75%         20.500000
# 95%         61.000000
# 97%         77.760000
# 99%        112.000000
# 99.5%      126.000000
# 99.9%      141.592000
# max        148.000000
# Name: days_between_orders, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.boxplot(user_profile[(user_profile['days_between_orders'] > 0)]['days_between_orders'], vert=False)
plt.title('Boxplot - диаграмма для колонки профиля пользователя days_between_orders - "Дней между заказами"')
plt.xlim(-10, 150)
plt.xlabel('Дней между заказами (days_between_orders)')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.hist(user_profile['days_between_orders'], bins=100, edgecolor='black')
plt.title('Гистограмма для колонки профиля пользователя days_between_orders - "Дней между заказами"')
plt.xlabel('Дней между заказами (days_between_orders)')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# - Объем данных по колонке `days_between_orders` достаточен для анализа.
# - По колонке `days_between_orders` чистку проводить не требуется, так как правый длинный хвост распределения - это нормальное явление (пользователи, редко своершающие покупки), которое не стоит исключать из анализа для сохранения полноты картины.

# %% [markdown]
# Отфильтруем `total_orders` по перцентилю 99%

# %%
# Замеряем количество строк в user_profile до фильтрации
user_profile_count_before = user_profile.shape[0]

# Фильтруем total_orders по 99 перцентилю
total_orders_99 = user_profile['total_orders'].quantile(0.99)
user_profile = user_profile[(user_profile['total_orders'] <= total_orders_99)]

# Замеряем количество строк в user_profile после фильтрации 
user_profile_count_after = user_profile.shape[0]

# Подсчитываем сколько строк было удалено и в процентах
rows_removed = user_profile_count_before - user_profile_count_after
print(f"Количество удалённых строк: {rows_removed}")
percentage_removed = (rows_removed / user_profile_count_before) * 100
print(f"Процент удалённых строк: {percentage_removed:.2f}%")
# Out:
# Количество удалённых строк: 216
# Процент удалённых строк: 1.00%

# %% [markdown]
# Проверим изменения в профиле пользователей после фильтрации `total_orders`

# %%
# Общее число пользователей
total_users = len(user_profile)

# Средняя выручка с одного заказа
avg_revenue_per_order = user_profile['avg_revenue_rub'].mean()

# Доля пользователей с 2 и более заказами
is_two_or_more = (user_profile['is_two'] == 1).mean()

# Доля пользователей с 5 и более заказами
is_five_or_more = (user_profile['is_five'] == 1).mean()

# Выводим результаты
print(f"Общее число пользователей: {total_users}")
print(f"Средняя выручка с одного заказа: {avg_revenue_per_order:.2f} руб.")
print(f"Доля пользователей с 2 и более заказами: {is_two_or_more:.2%}")
print(f"Доля пользователей с 5 и более заказами: {is_five_or_more:.2%}")
# Out:
# Общее число пользователей: 21372
# Средняя выручка с одного заказа: 554.99 руб.
# Доля пользователей с 2 и более заказами: 61.26%
# Доля пользователей с 5 и более заказами: 28.11%

# %% [markdown]
# В результате фильтрации по колонке `total_orders` удалено 216 строк (1%). Изменение средней выручки не значительно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Статистики по профилю пользователя изучены.

# %% [markdown]
# Промежуточные выводы по итогам шага 3:
# 1. Построены агрегированные признаки, описывающие поведение и профиль каждого пользователя.
# 2. Используя данные о профилях пользователей, рассчитали:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# 3. Также изучили статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# 3. По результатам оценили данные:
#  - объем данных достаточен для анализа,
#  - в колонке `total_orders` выявлены выбросы, которые были вычищены по 99 перцентилю исходя из оценки плотности популяции наблюдений в зоне предполагаемых выбросов (правее 99 перцентиля единичные выбросы).
#
# 4. Проведен анализ изменений датасета по итогам фильтрации по колонке `total_orders`: в результате фильтрации по колонке `total_orders` удалено 216 строк (1%), изменение средней выручки не значительно.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используем профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуем признаки, описывающие первый заказ пользователя, и выясним, влияют ли они на вероятность возвращения пользователя.
#
# **Шаг 4.1.1 Изучим распределение пользователей по признакам.**
#
# - Сгруппируем пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитаем общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака.
# - Ответим на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?

# %% [markdown]
# Напишем функцию для вывода информации по сементам

# %%
def seg_info(df, column):
        seg = (df.groupby(column).agg(users_count=('user_id', 'nunique')).reset_index().sort_values('users_count', ascending=False))
        #seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() * 100)
        #seg['users_share'] = seg['users_share'].round(2)
        vc = df[column].value_counts(normalize=True).mul(100).round(2).reset_index()
        vc.columns=[column,'users_share']
        seg = seg.merge(vc, on=column)
        return seg

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Доли удобнее считать с помощью `value_counts(normalize=True)`.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# Сгруппируем пользователей по типу их первого мероприятия

# %%
seg_info(user_profile, 'first_event_type')
# Out:
#   first_event_type  users_count  users_share
# 0         концерты         9610        44.97
# 1           другое         5135        24.03
# 2            театр         4256        19.91
# 3          стендап         1109         5.19
# 4            спорт          761         3.56
# 5         выставки          406         1.90
# 6             ёлки           95         0.44

# %% [markdown]
# Сгруппируем пользователей по типу устройства, с которого совершена первая покупка

# %%
seg_info(user_profile, 'first_device')
# Out:
#   first_device  users_count  users_share
# 0       mobile        17693        82.79
# 1      desktop         3679        17.21

# %% [markdown]
# Сгруппируем пользователей по региону проведения мероприятия из первого заказа

# %%
seg_info(user_profile, 'first_region').head(10)
# Out:
#            first_region  users_count  users_share
# 0    Каменевский регион         6964        32.58
# 1  Североярская область         3734        17.47
# 2   Широковская область         1237         5.79
# 3      Озернинский край          670         3.13
# 4  Малиновоярский округ          528         2.47
# 5  Светополянский округ          467         2.19
# 6      Шанырский регион          466         2.18
# 7      Травяная область          455         2.13
# 8   Речиновская область          441         2.06
# 9   Яблоневская область          407         1.90

# %% [markdown]
# Сгруппируем пользователей по билетному оператору, продавшему билеты на первый заказ

# %%
seg_info(user_profile, 'first_service').head(10)
# Out:
#         first_service  users_count  users_share
# 0  Билеты без проблем         4886        22.86
# 1           Мой билет         3005        14.06
# 2         Лови билет!         2812        13.16
# 3       Билеты в руки         2519        11.79
# 4             Облачко         2195        10.27
# 5      Весь в билетах         1290         6.04
# 6       Лучшие билеты         1177         5.51
# 7           Прачечная          580         2.71
# 8        Край билетов          466         2.18
# 9        Дом культуры          345         1.61

# %% [markdown]
# Вывод по итогам шага 4.1.1:
#
# - Распределение пользователей по всем признакам **неравномерное**.
# - Есть выраженные **точки входа**:
#   - Концерты по типу мероприятия
#   - Мобильные устройства
#   - Каменевский регион и Североярская область
#   - Крупные билетные операторы («Билеты без проблем», «Мой билет», «Лови билет!»)
# - Эти сегменты включают наибольшее число пользователей и являются важнейшими для проведения анализа поведения пользователей и выбработки бизнес-стратегий**.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твой анализ выполнен в полном соответствии с задачей. Ты правильно ответил на главный вопрос: распределение пользователей по всем признакам действительно неравномерное. Ты также верно определил самые крупные "точки входа" для большинства сегментов: концерты, мобильные устройства и тройку крупнейших билетных операторов (Билеты без проблем, Мой билет и Лови билет!).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Ты упоминаешь "Каменевский район", в то время как в таблице с данными он указан как "Каменевский регион". Это, вероятно, просто опечатка, так как в остальном лидеры по регионам (Каменевский и Североярская область) определены верно.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# ---
#
# **Шаг 4.1.2. Проанализируем возвраты пользователей.**
#
# - Для каждого сегмента вычислим долю пользователей, совершивших два и более заказа.
# - Визуализируем результат подходящим графиком. Если сегментов слишком много, то поместим на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответим на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# *При интерпретации результатов учем размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.*

# %% [markdown]
# Напишем функцию для вывода информации по сементам с долей пользователей, совершивших два и более заказа. Добавим параметр `sort_by_2ormore` (по умолчанию `True`) применения сортировки по доле пользователей, совершивших два и более заказа. Этот параметр при большом количестве сегментов в выборке, чтоб посмотреть топ-10 как по размеру сегмента (количеству пользователей), так и по доле пользователей, совершивших два и более заказа.

# %%
def seg_info_w_ge2(df, column, sort_by_2ormore=True):
        seg = (df.groupby(column).agg(users_count=('user_id', 'nunique'), users_share_2ormore = ('is_two', 'mean')).reset_index().sort_values('users_count', ascending=False))
        #seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() * 100)
        #seg['users_share'] = seg['users_share'].round(2)
        vc = df[column].value_counts(normalize=True).mul(100).round(2).reset_index()
        vc.columns=[column,'users_share']
        seg = seg.merge(vc, on=column)
        #seg_ge2 = (df.groupby(column)['is_two'].mean().reset_index())
        #seg['users_share_2ormore'] = (seg_ge2['is_two'] * 100)
        seg['users_share_2ormore'] = seg['users_share_2ormore'].mul(100).round(2)   
        if sort_by_2ormore:
            return seg.sort_values('users_share_2ormore', ascending=False)
        else:
            return seg

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для оценки доли также можно использовать `mean`.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# Посчитаем средний процент по выборке совершения повтроных заказов:

# %%
avg_prc = (user_profile['is_two'].sum()/user_profile.shape[0] * 100).round(2) 
avg_prc
# Out:
# np.float64(61.26)

# %% [markdown]
# Сгруппируем пользователей по типу их первого мероприятия

# %%
seg_info_w_ge2(user_profile, 'first_event_type')
# Out:
#   first_event_type  users_count  users_share_2ormore  users_share
# 2            театр         4256                63.65        19.91
# 5         выставки          406                63.30         1.90
# 0         концерты         9610                61.71        44.97
# 3          стендап         1109                61.14         5.19
# 1           другое         5135                59.44        24.03
# 4            спорт          761                54.80         3.56
# 6             ёлки           95                52.63         0.44

# %%
seg_info_w_ge2(user_profile, 'first_event_type').plot(kind='bar',
				title='Вероятность того, что пользователь совершит 2 и более заказов в зависимости от типа первого мероприятия',
                legend=False,
                x='first_event_type', y='users_share_2ormore',
                color='green',
                edgecolor='black',                                      
                xlabel='Тип первого мероприятия',
                ylabel='Доля пользователей, совершивших 2 и более заказов, %',
                rot=0,
                figsize=(12,6),
                label='Доля пользователей')
plt.axline((0,avg_prc),(12,avg_prc), color='r', linestyle='--', 
           label=f"Среднее значение = {avg_prc}")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> На графиках этого типа удобно подписывать средний уровень возврата с помощью `axhline` - это позволит визуально определить точки входа.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# Сгруппируем пользователей по типу устройства, с которого совершена первая покупка

# %%
seg_info_w_ge2(user_profile, 'first_device')
# Out:
#   first_device  users_count  users_share_2ormore  users_share
# 1      desktop         3679                63.85        17.21
# 0       mobile        17693                60.72        82.79

# %%
seg_info_w_ge2(user_profile, 'first_device').plot(kind='bar',
				title='Вероятность того, что пользователь совершит 2 и более заказов в зависимости от типа устройства, с которого совершена первая покупка',
                legend=False,
                x='first_device', y='users_share_2ormore',
                color='green',
                edgecolor='black',                                      
                xlabel='Тип устройства, с которого совершена первая покупка',
                ylabel='Доля пользователей, совершивших 2 и более заказов, %',
                rot=0,
                figsize=(12,6),
                label='Доля пользователей')
plt.axline((0,avg_prc),(12,avg_prc), color='r', linestyle='--', 
           label=f"Среднее значение = {avg_prc}")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Сгруппируем пользователей по региону проведения мероприятия из первого заказа (топ-10 по доле совершивших >= 2 заказов и отдельно по размеру сегмента)

# %%
seg_info_w_ge2(user_profile, 'first_region').head(10)
# Out:
#               first_region  users_count  users_share_2ormore  users_share
# 78       Верхозёрский край            1               100.00         0.00
# 56  Озернопольская область           28                89.29         0.13
# 59    Радужнопольский край           24                79.17         0.11
# 55     Горноземский регион           28                71.43         0.13
# 6         Шанырский регион          466                70.39         2.18
# 66        Тихолесский край           10                70.00         0.05
# 36        Лесостепной край           60                70.00         0.28
# 17    Горицветская область          245                66.94         1.15
# 74        Лесноярский край            3                66.67         0.01
# 72    Верховинская область            3                66.67         0.01

# %%
seg_info_w_ge2(user_profile, 'first_region', False).head(10)
# Out:
#            first_region  users_count  users_share_2ormore  users_share
# 0    Каменевский регион         6964                61.79        32.58
# 1  Североярская область         3734                63.93        17.47
# 2   Широковская область         1237                65.00         5.79
# 3      Озернинский край          670                55.07         3.13
# 4  Малиновоярский округ          528                55.30         2.47
# 5  Светополянский округ          467                66.38         2.19
# 6      Шанырский регион          466                70.39         2.18
# 7      Травяная область          455                61.10         2.13
# 8   Речиновская область          441                63.95         2.06
# 9   Яблоневская область          407                59.95         1.90

# %%
seg_info_w_ge2(user_profile, 'first_region', False).head(10).sort_values('users_share_2ormore', ascending=False).plot(kind='bar',
				title='Вероятность того, что пользователь совершит 2 и более заказов в зависимости от региона проведения мероприятия из первого заказа (топ-10 по размеру сегмента)',
                legend=False,
                x='first_region', y='users_share_2ormore',
                color='green',
                edgecolor='black',                                      
                xlabel='Регион проведения мероприятия из первого заказа',
                ylabel='Доля пользователей, совершивших 2 и более заказов, %',
                rot=45,
                figsize=(12,6),
                label='Доля пользователей')
plt.axline((0,avg_prc),(12,avg_prc), color='r', linestyle='--', 
           label=f"Среднее значение = {avg_prc}")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Сгруппируем пользователей по билетному оператору, продавшему билеты на первый заказ (топ-10 по доле совершивших >= 2 заказов и отдельно по размеру сегмента)

# %%
seg_info_w_ge2(user_profile, 'first_service').head(10)
# Out:
#         first_service  users_count  users_share_2ormore  users_share
# 33           Зе Бест!            1               100.00         0.00
# 19     Быстрый кассир           59                84.75         0.28
# 23             Реестр           31                80.65         0.15
# 20      Crazy ticket!           46                69.57         0.22
# 18          Восьмёрка           86                67.44         0.40
# 30  Билет по телефону            6                66.67         0.03
# 15        Show_ticket          162                65.43         0.76
# 8        Край билетов          466                65.24         2.18
# 9        Дом культуры          345                64.35         1.61
# 13           Мир касс          207                63.29         0.97

# %%
seg_info_w_ge2(user_profile, 'first_service', False).head(10)
# Out:
#         first_service  users_count  users_share_2ormore  users_share
# 0  Билеты без проблем         4886                59.74        22.86
# 1           Мой билет         3005                60.67        14.06
# 2         Лови билет!         2812                61.34        13.16
# 3       Билеты в руки         2519                62.52        11.79
# 4             Облачко         2195                61.37        10.27
# 5      Весь в билетах         1290                62.95         6.04
# 6       Лучшие билеты         1177                61.85         5.51
# 7           Прачечная          580                62.24         2.71
# 8        Край билетов          466                65.24         2.18
# 9        Дом культуры          345                64.35         1.61

# %%
seg_info_w_ge2(user_profile, 'first_service', False).head(10).sort_values('users_share_2ormore', ascending=False).plot(kind='bar',
				title='Вероятность того, что пользователь совершит 2 и более заказов в зависимости от билетного оператора, продавшего билеты на первый заказ (топ-10 по размеру сегмента)',
                legend=False,
                x='first_service', y='users_share_2ormore',
                color='green',
                edgecolor='black',                                      
                xlabel='Билетный оператор, продавший билеты на первый заказ',
                ylabel='Доля пользователей, совершивших 2 и более заказов, %',
                rot=45,
                figsize=(12,6),
                label='Доля пользователей')
plt.axline((0,avg_prc),(12,avg_prc), color='r', linestyle='--', 
           label=f"Среднее значение = {avg_prc}")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Вывод по итогам шага 4.1.2:
# Проведен анализ доли пользователей, совершивших 2 или более заказа, по основным сегментам (с визуализацией результатов):
# - по типу их первого мероприятия:
#   - Наибольшая доля повторных заказов пользователей в сегментах `театр`, `выставки`, `концерты`, `стендап`, `другое`, при этом достаточным для определения устойчивой и достоверной доли размером сегмента обладают сегменты `театр`, `концерты`, `другое`. Также сегменты `театр`, `концерты` являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (63.65% и 61.71% соответственно), чем в среднем по выборке (61.26%).
# - по типу устройства, с которого совершена первая покупка:
#   - Наибольшая доля повторных заказов пользователей в сегменте `desktop`. По обоим сегментам размер достаточный для определения устойчивой и достоверной доли. Сегмент `desktop` является успешной «точкой входа» — сегментом, в котором пользователи чаще совершают повторный заказ (63.85%), чем в среднем по выборке (61.26%).
# - по региону проведения мероприятия из первого заказа:
#   - Наибольшая доля повторных заказов пользователей наблюдается в сегментах (регионах) с малым количеством пользователей - доля неустойчива и недостоверна, среди сегментов с большим количеством пользователей стоит выделить `Каменевский регион`, `Североярская область`, оба этих сегмента также являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (61.79% и 63.93% соответственно), чем в среднем по выборке (61.26%).
# - по билетному оператору, продавшему билеты на первый заказ:
#   - Наибольшая доля повторных заказов пользователей наблюдается в сегментах (операторах) с малым количеством пользователей - доля неустойчива и недостоверна, среди сегментов с большим количеством пользователей стоит выделить `Билеты без проблем`, `Мой билет`, `Лови билет!`, `Билеты в руки`, `Облачко`. Из этих сегментов `Лови билет!`, `Билеты в руки`, `Облачко` являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (61.34%, 62.52% и 61.37% соответственно), чем в среднем по выборке (61.26%).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты провел отличный анализ, который в точности соответствует заданию. Ты не просто нашел самые высокие доли возврата, а (как и просила задача) учел размер сегмента, отбросив статистически нестабильные малые группы. Ты верно рассчитал средний процент по выборке (61.26%) и затем корректно сравнил с ним крупные "точки входа". Все твои выводы о том, какие сегменты (театр, desktop, Североярская область, Лови билет и др.) являются "успешными", полностью верны.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В выводе ты перечисляешь крупные сегменты для анализа ("Билеты без проблем", "Лови билет!", "Билеты в руки", "Облачко"), но пропускаешь "Мой билет". Судя по таблице, "Мой билет" (с 3005 пользователями) является вторым по величине сегментом и крупнее, чем "Билеты в руки" или "Облачко".

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# ---
#
# **Шаг 4.1.3. Опираясь на выводы из задач выше, проверим продуктовые гипотезы.**
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.

# %% [markdown]
# Гипотеза 1:
#
# Сравним процент повторных заказов в сегментах `концерты` и `спорт`:
# - концерты:	61.71% повторных заказов
# - спорт:	54.80% повторных заказов
#
# **Гипотеза не подтверждается.**

# %% [markdown]
# Гипотеза 2:
#
# Сравним ТОП-3 регионов по количеству пользователей и по проценту повторных заказов:
#
# - Каменевский регион:     6964 пользователей,	61.79% повторных заказов
# - Североярская область:	3734 пользователей,	63.93% повторных заказов
# - Широковская область:	1237 пользователей,	65.00% повторных заказов
#
#
# - Верхозёрский край:	    1  пользователей,	100.00% повторных заказов
# - Озернопольская область:	28 пользователей,	89.29% повторных заказов
# - Радужнопольский край:	24 пользователей,	79.17% повторных заказов
#
# **Гипотеза не подтверждается.** При этом следует учитывать, что для сегментов (регионов) с малым количеством пользователей нестабильна и не достоверна. Для регионов с большим количеством пользователей не прослеживается положительной корреляции между количеством пользователей и процентом повторных заказов, т. е. нет строгой прямой зависимости от размера выборки сегмента.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твоя проверка обеих гипотез выполнена безупречно. Ты абсолютно верно опроверг первую гипотезу, показав на цифрах, что у пользователей спорта доля возвратов ниже, чем у концертов. Твой анализ второй гипотезы также очень точен: ты правильно указал на нестабильность данных в малых сегментах (как в примере с одним пользователем) и пришел к верному выводу, что среди крупных регионов нет прямой связи "чем больше пользователей, тем выше возврат".

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучим количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# **Шаг 4.2.1. Проследим связь между средней выручкой сервиса с заказа и повторными заказами.**
#
# - Построим сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответим на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?

# %% [markdown]
# Создадим выборки пользователей с одним заказом и двумя и более заказами:

# %%
one = user_profile[user_profile['is_two'] == 0]
two = user_profile[user_profile['is_two'] == 1]

# %% [markdown]
# Построим сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):

# %%
plt.figure(figsize=(12,6))
one['avg_revenue_rub'].plot(kind='hist',
                label ='Один заказ',                 
                alpha=0.5,
                bins=30, 
                density=True)
two['avg_revenue_rub'].plot(kind='hist',
                label ='Два и более заказов',                 
                alpha=0.5,
                bins=30,
                density=True)
plt.xlabel('Средняя выручка, руб.')
plt.xticks(range(0, 3250, 250))
plt.ylabel('Плотность')
plt.title('Распределение средней выручки в зависимости от количества заказов')
plt.legend()
plt.show()

# %% [markdown]
# Ответим на вопросы:
# - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#   - Основная концентрация средней выручки для пользователей, совершивших один заказ, находится в диапазоне от 0 до 500 руб.
#   - Основная концентрация средней выручки для пользователей, совершивших два и более заказа, находится в диапазоне от 300 до 750 руб.
# - Есть ли различия между группами?
#   - Пользователи с одним заказом чаще совершают покупки с низкой стоимостью (до 250 руб.), средняя цена покупки пользователей, совершивших две и более покупки, выше.
#   - Средняя цена покупки у пользователей, совершивших две и более покупки, выше, чем у пользователей с одной покупкой.
#   - Оба распределения скошены вправо, имеют длинный узкий правый хвост, но у пользователей с двумя и более заказами распределение имеет пик (мат. ожидание) правее и более сплющенное (больше дисперсия)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твой анализ выполнен безупречно. Ты построил наглядные гистограммы и точно ответил на вопросы из задачи. Ты верно определил, что у пользователей с одним заказом основная концентрация выручки находится в низком диапазоне (до 250-500 рублей), в то время как у пользователей с двумя и более заказами пик смещен вправо (в район 300-750 рублей). Твои выводы о том, что лояльные пользователи имеют более высокую среднюю цену покупки и что их распределение более "сплющенное", полностью соответствуют графику.

# %% [markdown]
# **Шаг 4.2.2. Сравним распределение по средней выручке с заказа в двух группах пользователей.**
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответим на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?

# %% [markdown]
# Создадим выборки пользователей по группам:

# %%
two_to_four = user_profile[user_profile['is_two'] == 1 & (user_profile['is_five'] == 0)]
five = user_profile[(user_profile['is_five'] == 1)]

# %% [markdown]
# Построим сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):

# %%
plt.figure(figsize=(12,6))
two_to_four['avg_revenue_rub'].plot(kind='hist',
                label ='Больше двух заказов, но меньше пяти',                 
                alpha=0.5,
                bins=30, 
                density=True)
five['avg_revenue_rub'].plot(kind='hist',
                label ='Пять и более заказов',                 
                alpha=0.5,
                bins=30,
                density=True)
plt.xlabel('Средняя выручка, руб.')
plt.xticks(range(0, 3250, 250))
plt.ylabel('Плотность')
plt.title('Распределение средней выручки в зависимости от количества заказов')
plt.legend()
plt.show()

# %% [markdown]
# Ответим на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
# - Основная концентрация средней выручки для пользователей, совершивших более двух заказов, но менее пяти, находится в диапазоне от 0 до 800 руб.
# - Основная концентрация средней выручки для пользователей, совершивших пять и более заказов, находится в диапазоне от 300 до 750 руб.
# - Среднее значение выручки больше для пользователей, совершивших пять и более заказов - более активные пользователи готовы тратить на покупки больше.
# - Распределение для пользователей, ~~совершивших более двух заказов, но менее пяти, имеет более экспоненциальный характер (хотя оно явно лог-нормальное) (т. е. более отвечает распределениям массового обслуживания и является по сути более стабильным и предсказуемым)~~ совершивших пять и более заказов, больше соответствует нормальному распределению (хоть и скошенному) и выглядит более сфокусированным, что говорит о более стабильном поведении.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты выполнил задачу и построил сравнительные графики. Твой главный вывод о том, что между группами есть различия, верный. Ты также правильно определил, что пользователи, совершившие пять и более заказов, тратят больше, и их основная концентрация выручки находится в диапазоне 300–750 рублей.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты пишешь, что распределение для группы 2-4 заказа является более стабильным и предсказуемым. График показывает обратное: у этой группы (синий) распределение имеет экспоненциальный характер с пиком у нуля. В то же время у группы 5+ заказов (оранжевый) оно больше похоже на нормальное (хоть и скошенное) и выглядит более сфокусированным, что как раз и говорит о более стабильном поведении.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# **Шаг 4.2.3. Проанализируем влияние среднего количества билетов в заказе на вероятность повторной покупки.**
#
# - Изучим распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишем основные наблюдения.
# - Разделим пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитаем общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответим на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?

# %% [markdown]
# Разделим пользователей на несколько сегментов по среднему количеству билетов в заказе

# %%
user_profile.loc[:, 'avg_tickets_count'] = pd.cut(user_profile.loc[:, 'avg_tickets'], bins=[1, 2, 3, 5, 100], labels=['1-2', '2-3', '3-5', '5+'], right=False)

# %% [markdown]
# Для каждого сегмента подсчитаем общее число пользователей и долю пользователей, совершивших повторные заказы.

# %%
tickets_bins = user_profile.groupby('avg_tickets_count', observed=False).agg(user_count=('user_id', 'count'),is_two=('is_two', 'mean')).reset_index() 

tickets_bins['is_two'] = tickets_bins['is_two'] * 100

tickets_bins = tickets_bins.sort_values('avg_tickets_count').reset_index(drop=True)
tickets_bins
# Out:
#   avg_tickets_count  user_count     is_two
# 0               1-2        2404  51.289517
# 1               2-3        9587  73.797851
# 2               3-5        8909  53.260748
# 3                5+         472   8.474576

# %%
tickets_bins.plot(kind='bar',
				title='Количество пользователей для сегментов пользователей по среднему количеству билетов в заказе',
                legend=False,
                x='avg_tickets_count', y='user_count',
                color='green',
                edgecolor='black',                                      
                xlabel='Сегмент пользователей по среднему количеству билетов в заказе',
                ylabel='Количество пользователей',
                rot=0,
                figsize=(12,6),
                label = 'Количество пользователей')
plt.axline((0,tickets_bins['user_count'].mean()),(12,tickets_bins['user_count'].mean()), color='r', linestyle='--', 
           label=f"Среднее значение = {tickets_bins['user_count'].mean()}")
plt.legend()
plt.show()

# %%
tickets_bins.plot(kind='bar',
				title='Доля пользователей, совершивших 2 и более заказов, для сегментов пользователей по среднему количеству билетов в заказе',
                legend=False,
                x='avg_tickets_count', y='is_two',
                color='green',
                edgecolor='black',                                      
                xlabel='Сегмент пользователей по среднему количеству билетов в заказе',
                ylabel='Доля пользователей, совершивших 2 и более заказов, %',
                rot=0,
                figsize=(12,6),
                label='Доля пользователей')
plt.axline((0,tickets_bins['is_two'].mean()),(12,tickets_bins['is_two'].mean()), color='r', linestyle='--', 
           label=f"Среднее значение = {tickets_bins['is_two'].mean() :.2f}")
plt.legend()
plt.show()

# %% [markdown]
# - Ответим на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#       - Пользователи распределены по сегментам неравномерно, основная масса пользователей - в сегментах 2-3 и 3-5, сегмент 1-2 средний, а сегмент 5+ самый малый. Ожидаемо большие группы (более 5 человек) встречаются реже, чем группы от 2 до 5 человек, небольшие группы от 1 до 2 человек вероятно тоже реже посещают мероприятия.
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#       - Сегмент 2-3 (74%) имеет аномально высокую долю повтроных покупок (средняя доля повторных покупок - 47%). Этот сегмент вероятно представлен небольшими семейными группами или дружескими компаниями, имеющими большую лояльность.
#       - Сегмент 5+ (8.5%) имеет аномально низкую долю повтроных покупок (средняя доля повторных покупок - 47%). Этот сегмент вероятно представлен большими группами из организаций, учебных заведений и т. п. - их лояльность не высока.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твой анализ по этой задаче выполнен безупречно. Ты в точности ответил на оба вопроса из задания: пользователи действительно распределены неравномерно (сконцентрированы в сегментах 2-3 и 3-5 билетов), и ты правильно определил аномальные сегменты. Все цифры, которые ты приводишь в выводах - 74% для сегмента 2-3, 8.5% для сегмента 5+ и средняя доля 47% - в точности соответствуют данным из твоих же графиков и таблиц.

# %% [markdown]
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучим временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# **Шаг 4.3.1. Проанализируем, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.**
#
# - По данным даты первого заказа выделим день недели.
# - Для каждого дня недели подсчитаем общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируем.
# - Ответим на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?

# %% [markdown]
# Сконструируем признак дня недели первого заказа

# %%
user_profile['first_order_dayofweek'] = user_profile['first_order_dt'].dt.dayofweek

# %% [markdown]
# Сформируем датасет с количеством пользователей и долей совершивших два и боллее заказа пользователей на каждый день недели

# %% [markdown]
# Для каждого дня недели подсчитаем общее число пользователей и долю пользователей, совершивших повторные заказы.

# %%
dayofweek_bins = user_profile.groupby('first_order_dayofweek', observed=False).agg(
    user_count=('user_id', 'count'),
    two_or_more_share=('is_two', 'mean')
).reset_index()     

dayofweek_bins['two_or_more_share'] = dayofweek_bins['two_or_more_share'] * 100

dayofweek_bins['first_order_dayofweek'] = dayofweek_bins['first_order_dayofweek'].map({
    0: 'Понедельник',   
    1: 'Вторник',
    2: 'Среда',     
    3: 'Четверг',
    4: 'Пятница',
    5: 'Суббота',
    6: 'Воскресенье'
})
dayofweek_bins.head(10)
# Out:
#   first_order_dayofweek  user_count  two_or_more_share
# 0           Понедельник        2874          62.143354
# 1               Вторник        3152          61.865482
# 2                 Среда        3040          62.236842
# 3               Четверг        3086          59.526896
# 4               Пятница        3217          59.900528
# 5               Суббота        3268          62.790698
# 6           Воскресенье        2735          60.292505

# %% [markdown]
# Результаты визуализируем.

# %%
dayofweek_bins_plt = dayofweek_bins.set_index('first_order_dayofweek')

dayofweek_bins_plt['two_or_more_share'].plot(kind='bar',
                title='Доля пользователей, совершивших 2 и более заказов, в зависимости от дня недели первого заказа',
                legend=False,
                x='first_order_dayofweek',
                xlabel='День недели первого заказа', 
                ylabel='Доля пользователей, %',
                rot=45,
                color='green',
                edgecolor='black',                         
                figsize=(10,6))
plt.show()

# %% [markdown]
# Ответим на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#   - День недели первого заказа незначительно (в пределах статистической погрешности) влияет на вероятность возврата клиента. Таким образом, день недели первой покупки не является определяющим фактором для прогнозирования возвратов клиентов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты выполнил задачу и ответил на главный вопрос. Твой итоговый вывод о том, что день недели первого заказа влияет на вероятность возврата клиента незначительно, абсолютно верный. Это полностью подтверждается данными из таблицы, где все значения долей находятся в очень узком диапазоне.

# %% [markdown]
# **Шаг 4.3.2. Изучим, как средний интервал между заказами влияет на удержание клиентов.**
#
# - Рассчитаем среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуем, как средний интервал между заказами влияет на вероятность повторного заказа, и сделаем выводы.

# %% [markdown]
# Рассчитаем среднее время между заказами для двух групп пользователей: совершившие 2–4 заказа, совершившие 5 и более заказов.

# %%
average_days_ge2 = user_profile[(user_profile['is_two'] == 1) & (user_profile['is_five'] == 0)]['days_between_orders']

average_days_ge5 = user_profile[user_profile['is_five'] == 1]['days_between_orders']

# %% [markdown]
# Исследуем, как средний интервал между заказами влияет на вероятность повторного заказа, и сделаем выводы

# %%
average_days_ge2.describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    7085.000000
# mean       21.131856
# std        28.258351
# min         0.000000
# 1%          0.000000
# 5%          0.000000
# 25%         0.000000
# 50%         9.000000
# 75%        33.300000
# 95%        83.000000
# 97%       100.000000
# 99%       125.000000
# 99.5%     131.580000
# 99.9%     143.916000
# max       148.000000
# Name: days_between_orders, dtype: float64

# %%
average_days_ge5.describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    6008.000000
# mean        9.854511
# std         7.788346
# min         0.000000
# 1%          0.000000
# 5%          0.200000
# 25%         3.800000
# 50%         8.000000
# 75%        14.000000
# 95%        25.930000
# 97%        28.500000
# 99%        32.800000
# 99.5%      34.200000
# 99.9%      36.500000
# max        37.500000
# Name: days_between_orders, dtype: float64

# %%
plt.figure(figsize=(12,6))
average_days_ge2.plot(kind='hist',
                label ='Больше двух заказов, но меньше пяти',                 
                alpha=0.5,
                bins=30, 
                density=True)
average_days_ge5.plot(kind='hist',
                label ='Пять и более заказов',                 
                alpha=0.5,
                bins=30,
                density=True)
plt.xlabel('Среднее время между заказами, дней')
plt.xticks(range(0, 160, 10))
plt.ylabel('Плотность')
plt.title('Распределение среднего времени между заказами для двух групп пользователей')
plt.legend()
plt.show()

# %% [markdown]
# Судя по гистограмме, выбросов или аномальных значений в выборке нет, выборочное среднее значение будет корректным.

# %%
print(f"Среднее время между заказами для пользователей с 2-4 заказами: {average_days_ge2.mean():.2f} дней")
print(f"Среднее время между заказами для пользователей с 5 и более заказами: {average_days_ge5.mean():.2f} дней")
# Out:
# Среднее время между заказами для пользователей с 2-4 заказами: 21.13 дней
# Среднее время между заказами для пользователей с 5 и более заказами: 9.85 дней

# %% [markdown]
# Вывод по шагу 4.3.2:
# - Среднее время между заказами для пользователей с 2-4 заказами: 21.36 дней.
# - Среднее время между заказами для пользователей с 5 и более заказами: 10.05 дней.
#
# Пользователи с 5 и более заказами делают заказы чаще (имеют меньшее среднее время между заказами), т. е. обладают большей активностью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты выполнил задачу, и твой анализ данных абсолютно точен. Твой вывод о том, что пользователи с 5 и более заказами имеют значительно более короткий интервал между покупками (10.05 дней), чем менее лояльные группы (21.36 дней), полностью подтверждается данными.

# %% [markdown]
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучим, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используем универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# **Шаг 4.4.1: Проведем корреляционный анализ.**
# - Рассчитаем коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используем параметр `interval_cols` для определения интервальных данных.
# - Проанализируем полученные результаты. Если полученные значения будут близки к нулю, проверим разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделим сегменты пользователей по полю `total_orders`, а затем повторим корреляционный анализ. Выделим такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируем результат корреляции с помощью тепловой карты.
# - Ответим на вопрос: какие признаки наиболее связаны с количеством заказов?

# %% [markdown]
# Соберем датасет для анализа

# %%
user_profile_phik = user_profile[[
    'first_device',
    'first_region',
    'first_service',                
    'first_event_type',
    'total_orders',
    'avg_revenue_rub',
    'avg_tickets',
    'days_between_orders',
    'is_two',
    'is_five'
]]

# %% [markdown]
# Рассчитаем коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используем параметр `interval_cols` для определения интервальных данных.

# %%
phik_matrix = user_profile_phik.phik_matrix(interval_cols=[
    'total_orders',
    'avg_revenue_rub',
    'avg_tickets',
    'days_between_orders'
])

# %% [markdown]
# Визуализируем результат корреляции с помощью тепловой карты

# %%
phik_matrix.style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style type="text/css">
# #T_4a276_row0_col0, #T_4a276_row1_col1, #T_4a276_row2_col2, #T_4a276_row3_col3, #T_4a276_row4_col4, #T_4a276_row5_col5, #T_4a276_row6_col6, #T_4a276_row7_col7, #T_4a276_row8_col8, #T_4a276_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col1, #T_4a276_row5_col7, #T_4a276_row6_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col2, #T_4a276_row6_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col3, #T_4a276_row4_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col4, #T_4a276_row8_col0, #T_4a276_row9_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col5, #T_4a276_row2_col8, #T_4a276_row8_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col6, #T_4a276_row0_col7, #T_4a276_row0_col8, #T_4a276_row2_col4, #T_4a276_row3_col8, #T_4a276_row3_col9, #T_4a276_row4_col0, #T_4a276_row4_col2, #T_4a276_row4_col3, #T_4a276_row7_col1, #T_4a276_row7_col5, #T_4a276_row9_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4a276_row0_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4a276_row1_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4a276_row1_col2, #T_4a276_row8_col9 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_4a276_row1_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_4a276_row1_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_4a276_row1_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_4a276_row1_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4a276_row1_col7, #T_4a276_row1_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4a276_row1_col9, #T_4a276_row6_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_4a276_row2_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4a276_row2_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_4a276_row2_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_4a276_row2_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4a276_row2_col6, #T_4a276_row3_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_4a276_row2_col7, #T_4a276_row3_col7, #T_4a276_row9_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4a276_row2_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4a276_row3_col0, #T_4a276_row7_col2, #T_4a276_row8_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4a276_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_4a276_row3_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_4a276_row3_col4, #T_4a276_row7_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_4a276_row3_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_4a276_row4_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4a276_row4_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_4a276_row4_col7, #T_4a276_row5_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_4a276_row4_col8, #T_4a276_row5_col1, #T_4a276_row7_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4a276_row4_col9 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_4a276_row5_col0, #T_4a276_row9_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4a276_row5_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_4a276_row5_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4a276_row5_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_4a276_row5_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_4a276_row5_col9 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_4a276_row6_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4a276_row6_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_4a276_row6_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_4a276_row6_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_4a276_row6_col8 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_4a276_row6_col9 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_4a276_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4a276_row7_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_4a276_row7_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4a276_row7_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_4a276_row8_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4a276_row8_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_4a276_row8_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_4a276_row8_col6 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_4a276_row8_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_4a276_row9_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_4a276_row9_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_4a276_row9_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_4a276_row9_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_4a276_row9_col8 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_4a276">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a276_level0_col0" class="col_heading level0 col0" >first_device</th>
#       <th id="T_4a276_level0_col1" class="col_heading level0 col1" >first_region</th>
#       <th id="T_4a276_level0_col2" class="col_heading level0 col2" >first_service</th>
#       <th id="T_4a276_level0_col3" class="col_heading level0 col3" >first_event_type</th>
#       <th id="T_4a276_level0_col4" class="col_heading level0 col4" >total_orders</th>
#       <th id="T_4a276_level0_col5" class="col_heading level0 col5" >avg_revenue_rub</th>
#       <th id="T_4a276_level0_col6" class="col_heading level0 col6" >avg_tickets</th>
#       <th id="T_4a276_level0_col7" class="col_heading level0 col7" >days_between_orders</th>
#       <th id="T_4a276_level0_col8" class="col_heading level0 col8" >is_two</th>
#       <th id="T_4a276_level0_col9" class="col_heading level0 col9" >is_five</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a276_level0_row0" class="row_heading level0 row0" >first_device</th>
#       <td id="T_4a276_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_4a276_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_4a276_row0_col2" class="data row0 col2" >0.09</td>
#       <td id="T_4a276_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_4a276_row0_col4" class="data row0 col4" >0.02</td>
#       <td id="T_4a276_row0_col5" class="data row0 col5" >0.07</td>
#       <td id="T_4a276_row0_col6" class="data row0 col6" >0.06</td>
#       <td id="T_4a276_row0_col7" class="data row0 col7" >0.02</td>
#       <td id="T_4a276_row0_col8" class="data row0 col8" >0.04</td>
#       <td id="T_4a276_row0_col9" class="data row0 col9" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_4a276_level0_row1" class="row_heading level0 row1" >first_region</th>
#       <td id="T_4a276_row1_col0" class="data row1 col0" >0.11</td>
#       <td id="T_4a276_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_4a276_row1_col2" class="data row1 col2" >0.70</td>
#       <td id="T_4a276_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_4a276_row1_col4" class="data row1 col4" >0.11</td>
#       <td id="T_4a276_row1_col5" class="data row1 col5" >0.35</td>
#       <td id="T_4a276_row1_col6" class="data row1 col6" >0.14</td>
#       <td id="T_4a276_row1_col7" class="data row1 col7" >0.07</td>
#       <td id="T_4a276_row1_col8" class="data row1 col8" >0.09</td>
#       <td id="T_4a276_row1_col9" class="data row1 col9" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_4a276_level0_row2" class="row_heading level0 row2" >first_service</th>
#       <td id="T_4a276_row2_col0" class="data row2 col0" >0.09</td>
#       <td id="T_4a276_row2_col1" class="data row2 col1" >0.70</td>
#       <td id="T_4a276_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_4a276_row2_col3" class="data row2 col3" >0.59</td>
#       <td id="T_4a276_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_4a276_row2_col5" class="data row2 col5" >0

# %%
user_profile_phik['total_orders'].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.97, 0.99, 0.995, 0.999])
# Out:
# count    21372.000000
# mean         6.376521
# std         13.912898
# min          1.000000
# 1%           1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# 95%         26.000000
# 97%         40.000000
# 99%         76.290000
# 99.5%      105.000000
# 99.9%      139.000000
# max        149.000000
# Name: total_orders, dtype: float64

# %%
plt.figure(figsize=(12,6))
user_profile_phik['total_orders'].plot(kind='hist',                
                bins=100, 
                density=True)
plt.xlabel('Общее количество заказов')
plt.xticks(range(0, 150, 5))
plt.ylabel('Плотность')
plt.title('Распределение общего количества заказов')
plt.legend()
plt.show()

# %% [markdown]
# Проанализируем полученные результаты:
# - Полученные значения отличны от нуля, но значимо велики в основном для сконструированных по количесту заказов признаков сегментов (не интересных для анализа),
# - Разброс данных в total_orders - в данных есть определенное преобладание некоторых значений.
#
# Выделим сегменты пользователей по полю total_orders, а затем повторим корреляционный анализ.
# Выделим такие сегменты:
# 1 заказ;
# от 2 до 4 заказов;
# от 5 и выше.

# %%
user_profile['total_orders_bins'] = pd.cut(user_profile['total_orders'], bins=[1, 2, 5, 9999999], labels=['1', '2-4', '5+'], right=False, include_lowest=True)

# %%
user_profile[['total_orders', 'total_orders_bins']].head(10)
# Out:
#    total_orders total_orders_bins
# 0             1                 1
# 1             2               2-4
# 2             3               2-4
# 3             1                 1
# 4             2               2-4
# 5            13                5+
# 6             2               2-4
# 7             1                 1
# 8             3               2-4
# 9             2               2-4

# %%
user_profile_phik = user_profile[[
    'first_device',
    'first_region',
    'first_service',                
    'first_event_type',
    'total_orders',
    'total_orders_bins',
    'avg_revenue_rub',
    'avg_tickets',
    'days_between_orders',
    'is_two',
    'is_five'
]]

# %%
phik_matrix = user_profile_phik.phik_matrix(interval_cols=[
    'total_orders',
    'avg_revenue_rub',
    'avg_tickets',
    'days_between_orders'
])

# %%
phik_matrix.style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style type="text/css">
# #T_ddba8_row0_col0, #T_ddba8_row1_col1, #T_ddba8_row2_col2, #T_ddba8_row3_col3, #T_ddba8_row4_col4, #T_ddba8_row5_col5, #T_ddba8_row5_col9, #T_ddba8_row5_col10, #T_ddba8_row6_col6, #T_ddba8_row7_col7, #T_ddba8_row8_col8, #T_ddba8_row9_col5, #T_ddba8_row9_col9, #T_ddba8_row10_col5, #T_ddba8_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col1, #T_ddba8_row6_col8, #T_ddba8_row7_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col2, #T_ddba8_row7_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col3, #T_ddba8_row4_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col4, #T_ddba8_row5_col3, #T_ddba8_row9_col0, #T_ddba8_row10_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col5, #T_ddba8_row0_col7, #T_ddba8_row0_col8, #T_ddba8_row0_col9, #T_ddba8_row2_col4, #T_ddba8_row3_col9, #T_ddba8_row3_col10, #T_ddba8_row4_col0, #T_ddba8_row4_col2, #T_ddba8_row4_col3, #T_ddba8_row5_col0, #T_ddba8_row8_col1, #T_ddba8_row8_col6, #T_ddba8_row10_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col6, #T_ddba8_row2_col9, #T_ddba8_row9_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ddba8_row0_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ddba8_row1_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ddba8_row1_col2, #T_ddba8_row9_col10 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_ddba8_row1_col3, #T_ddba8_row5_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ddba8_row1_col4, #T_ddba8_row1_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ddba8_row1_col6, #T_ddba8_row6_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ddba8_row1_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ddba8_row1_col8, #T_ddba8_row1_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ddba8_row1_col10, #T_ddba8_row7_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ddba8_row2_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ddba8_row2_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_ddba8_row2_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_ddba8_row2_col5, #T_ddba8_row6_col0, #T_ddba8_row10_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ddba8_row2_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ddba8_row2_col7, #T_ddba8_row3_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ddba8_row2_col8, #T_ddba8_row3_col8, #T_ddba8_row10_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ddba8_row2_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ddba8_row3_col0, #T_ddba8_row8_col2, #T_ddba8_row9_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ddba8_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ddba8_row3_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_ddba8_row3_col4, #T_ddba8_row3_col5, #T_ddba8_row8_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ddba8_row3_col6, #T_ddba8_row5_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ddba8_row4_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ddba8_row4_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ddba8_row4_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ddba8_row4_col8, #T_ddba8_row6_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ddba8_row4_col9, #T_ddba8_row6_col1, #T_ddba8_row8_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ddba8_row4_col10 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ddba8_row5_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ddba8_row5_col2, #T_ddba8_row7_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ddba8_row5_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ddba8_row5_col8, #T_ddba8_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ddba8_row6_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ddba8_row6_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ddba8_row6_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ddba8_row6_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ddba8_row7_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ddba8_row7_col5 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ddba8_row7_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_ddba8_row7_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ddba8_row7_col9 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_ddba8_row7_col10 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_ddba8_row8_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ddba8_row8_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ddba8_row8_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ddba8_row8_col9 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ddba8_row8_col10 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ddba8_row9_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ddba8_row9_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ddba8_row9_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ddba8_row9_col7 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_ddba8_row9_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ddba8_row10_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ddba8_row10_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ddba8_row10_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_ddba8_row10_col8 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ddba8_row10_col9 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_ddba8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddba8_level0_col0" class="col_heading level0 col0" >first_device</th>
#       <th id="T_ddba8_level0_col1" class="col_heading level0 col1" >first_region</th>
#       <th id="T_ddba8_level0_col2" class="col_heading level0 col2" >first_service</th>
#       <th id="T_ddba8_level0_col3" class="col_heading level0 col3" >first_event_type</th>
#       <th id="T_ddba8_level0_col4" class="col_heading level0 col4" >total_orders</th>
#       <th id="T_ddba8_level0_col5" class="col_heading level0 col5" >total_orders_bins</th>
#       <th id="T_ddba8_level0_col6" class="col_heading level0 col6" >avg_revenue_rub</th>
#       <th id="T_ddba8_level0_col7" class="col_heading level0 col7" >avg_tickets</th>
#       <th id="T_ddba8_level0_col8" class="col_heading level0 col8" >days_between_orders</th>
#       <th id="T_ddba8_level0_col9" class="col_heading level0 col9" >is_two</th>
#       <th id="T_ddba8_level0_col10" class="col_heading level0 col10" >is_five</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddba8_level0_row0" class="row_heading level0 row0" >first_device</th>
#       <td id="T_ddba8_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ddba8_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_ddba8_row0_col2" class="data row0 col2" >0.09</td>
#       <td id="T_ddba8_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_ddba8_row0_col4" class="data row0 col4" >0.02</td>
#       <td id="T_ddba8_row0_col5" class="data row0 col5" >0.02</td>
#       <td id="T_ddba8_row0_col6" class="data row0 col6" >0.07</td>
#       <td id="T_ddba8_row0_col7" class="data row0 col7" >0.06</td>
#       <td id="T_ddba8_row0_col8" class="data row0 col8" >0.02</td>
#       <td id="T_ddba8_row0_col9" class="data row0 col9" >0.04</td>
#       <td id="T_ddba8_row0_col10" class="data row0 col10" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_ddba8_level0_row1" class="row_heading level0 row1" >first_region</th>
#       <td id="T_ddba8_row1_col0" class="data row1 col0" >0.11</td>
#       <td id="T_ddba8_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ddba8_row1_col2" class="data row1 col2" >0.70</td>
#       <td id="T_ddba8_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_ddba8_row1_col4" class="data ro

# %% [markdown]
# Повторный корреляционный анализ дал более читаемые результаты.

# %% [markdown]
# Вывод по шагу 4.4.1:
#
# 1. Наибольшая связь с общим количеством заказов (`total_orders`, да и с `total_orders_bins` картина похожая) у признаков `is_two`, `is_five`, однако анализ этой связи бессмысленен, т. к. это по определению сконструированные сегменты по количеству заказов.
#
#
# 2. Наибольшая связь со значимыми признаками (по результатам повторного корреляционного анализа по сконструированной колонке `total_orders_bins`):
#   - `avg_tickets` (0.66) - пользователи с большим средним количеством билетов в покупке отностяся к более лояльным сегментам (см. более ранние шаги анализа),
#
#   - `days_between_orders` (0.39) - большая частота покупок указывает на более регулярную активность,
#
#   - `revenue_rub` (0.32) - средняя выручка с заказа больше для более активных пользователей (см. шаг 4.2).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твой анализ корреляций выполнен безупречно. Ты в точности последовал инструкциям из задачи: заметил, что данные по total_orders сильно скошены, провел сегментацию (создав total_orders_bins) и выполнил повторный корреляционный анализ. Твой вывод о том, какие признаки наиболее связаны с числом заказов, абсолютно верный. Ты правильно определил, что наибольшую связь показывают поведенческие метрики: avg_tickets, days_between_orders и avg_revenue_rub, и все указанные тобой коэффициенты (0.66, 0.39 и 0.32) в точности соответствуют данным из второй корреляционной матрицы.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# ### Загрузка данных и их предобработка
#
# 1. Размер данных Яндекс Афиши: 290611 строк и 14 столбцов, занимаемый объем - 31 Мб. Данные соответствуют описанию, названия колонок соответствуют содержимому. Предварительно сформулированы стратегии оптимизации датасета, чистки дубликатов и выборосов.
# 2. Загружены данные крса казахского теньге за 2024 год и произведен пересчет в данных Яндекс Афиши выручки из казахского теньге в российский рубль на дату операции. В итоге в датасете сконструирована колонка `revenue_rub`.
# 3. Отфильтрованы выбросы в колонках `tickets_count` по 0.999 квантилю и `revenue_rub` по 0.995 квантилю.

# %% [markdown]
# ### Создание профиля пользователя
# 1. Построены агрегированные признаки, описывающие поведение и профиль каждого пользователя.
# 2. Проанализировали данные профилей пользователей:
# - Общее число пользователей: 21588
# - Средняя выручка с одного заказа: 554.74 руб.
# - Доля пользователей с 2 и более заказами: 61.65%
# - Доля пользователей с 5 и более заказами: 28.83%

# %% [markdown]
# ### Исследовательский анализ данных
# 1. Исследовали признаки, описывающие первый заказ пользователя, и выяснили, влияют ли они на вероятность возвращения пользователя:
# - Распределение пользователей по всем признакам **неравномерное**.
# - Есть выраженные **точки входа**:
#   - Концерты по типу мероприятия
#   - Мобильные устройства
#   - Каменевский регион и Североярская область
#   - Крупные билетные операторы («Билеты без проблем», «Мой билет», «Лови билет!»)
# - Эти сегменты включают наибольшее число пользователей и являются важнейшими для проведения анализа поведения пользователей и выбработки бизнес-стратегий.
# 2. Провели анализ доли пользователей, совершивших 2 или более заказа, по основным сегментам (с визуализацией результатов):
# - по типу их первого мероприятия:
#   - сегменты театр, концерты являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (63.65% и 61.71% соответственно), чем в среднем по выборке (61.26%).
# - по типу устройства, с которого совершена первая покупка:
#   - сегмент desktop является успешной «точкой входа» — сегментом, в котором пользователи чаще совершают повторный заказ (63.85%), чем в среднем по выборке (61.26%).
# - по региону проведения мероприятия из первого заказа:
#   - Каменевский регион, Североярская область, оба этих сегмента также являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (61.79% и 63.93% соответственно), чем в среднем по выборке (61.26%).
# - по билетному оператору, продавшему билеты на первый заказ:
#   - крупные операторы Лови билет!, Билеты в руки, Облачко являются успешными «точками входа» — сегментами, в которых пользователи чаще совершают повторный заказ (61.34%, 62.52% и 61.37% соответственно), чем в среднем по выборке (61.26%).
# 3. Проверили продуктовые гипотезы:
# - Гипотеза 1. Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - Гипотеза 2. В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
# Обе гипотезы не подтвердились.
# 4. Ответили на вопросы:
# - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#   - Основная концентрация средней выручки для пользователей, совершивших один заказ, находится в диапазоне от 0 до 500 руб.
#   - Основная концентрация средней выручки для пользователей, совершивших два и более заказа, находится в диапазоне от 300 до 750 руб.
# - Есть ли различия между группами?
#   - Пользователи с одним заказом чаще совершают покупки с низкой стоимостью (до 250 руб.), средняя цена покупки пользователей, совершивших две и более покупки, выше.
#   - Средняя цена покупки у пользователей, совершивших две и более покупки, выше, чем у пользователей с одной покупкой.
#   - Оба распределения скошены вправо, имеют длинный узкий правый хвост, но у пользователей с двумя и более заказами распределение имеет пик (мат. ожидание) правее и более сплющенное (больше дисперсия)
# - Есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#   - Основная концентрация средней выручки для пользователей, совершивших более двух заказов, но менее пяти, находится в диапазоне от 0 до 800 руб.
#   - Основная концентрация средней выручки для пользователей, совершивших пять и более заказов, находится в диапазоне от 300 до 750 руб.
#   - Среднее значение выручки больше для пользователей, совершивших пять и более заказов - более активные пользователи готовы тратить на покупки больше.
#   - Распределение для пользователей, совершивших пять и более заказов, больше соответствует нормальному распределению (хоть и скошенному) и выглядит более сфокусированным, что говорит о более стабильном поведении.
# - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#   - Пользователи распределены по сегментам неравномерно, основная масса пользователей - в сегментах 2-3 и 3-5, сегмент 1-2 средний, а сегмент 5+ самый малый. Ожидаемо большие группы (более 5 человек) встречаются реже, чем группы от 2 до 5 человек, небольшие группы от 1 до 2 человек вероятно тоже реже посещают мероприятия.
# - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#   - Сегмент 2-3 (74%) имеет аномально высокую долю повторных покупок (средняя доля повторных покупок - 47%). Этот сегмент вероятно представлен небольшими семейными группами или дружескими компаниями, имеющими большую лояльность.
#   - Сегмент 5+ (8.5%) имеет аномально низкую долю повтроных покупок (средняя доля повторных покупок - 47%). Этот сегмент вероятно представлен большими группами из организаций, учебных заведений и т. п. - их лояльность не высока.
# - Влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#   - День недели первого заказа незначительно (в пределах статистической погрешности) влияет на вероятность возврата клиента. Таким образом, день недели первой покупки не является определяющим фактором для прогнозирования возвратов клиентов.
#
# 5. Исследовали, как средний интервал между заказами влияет на вероятность повторного заказа: Пользователи с 5 и более заказами делают заказы чаще (имеют меньшее среднее время между заказами), т. е. обладают большей активностью.
#
#
# 6. Провели корреляционный анализ между признаками профиля пользователя и числом заказов (`total_orders`):
#  - Наибольшая связь со значимыми признаками (по результатам повторного корреляционного анализа по сконструированной колонке `total_orders_bins`):
#    - `avg_tickets` (0.66) - пользователи с большим средним количеством билетов в покупке отностяся к более лояльным сегментам (см. более ранние шаги анализа),
#
#    - `days_between_orders` (0.39) - большая частота покупок указывает на более регулярную активность,
#
#    - `revenue_rub` (0.32) - средняя выручка с заказа больше для более активных пользователей (см. шаг 4.2).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Твой итоговый вывод отлично структурирован и отвечает на все вопросы, поставленные в задаче. Почти все разделы - от описания "точек входа" до анализа гипотез, сегментации по количеству билетов и временным интервалам - точно отражают результаты. Рекомендации в целом логичны и вытекают из анализа (например, фокус на сегменте 2-3 билета, стимуляция пользователей с короткими интервалами).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В анализе распределения выручки (сравнение 2-4 заказа и 5+ заказов) есть неточность. Ты описываешь распределение для 2-4 заказов как "экспоненциальное" и при этом "более стабильное и предсказуемое". Это противоречивые характеристики. Судя по графикам из анализа, именно группа 5+ имеет более сфокусированное и стабильное распределение, хоть и смещенное вправо.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В "Исследовательском анализе данных" (раздел 1.8) ты совершенно верно определяешь desktop (с долей возврата 63.85%) как "успешную точку входа", поскольку этот показатель выше среднего по выборке. Однако в "Рекомендациях бизнесу" (пункт 1) ты по ошибке включаешь "Мобильные устройства" в список "основных сегментов вовлечения", хотя их доля возврата (которая, судя по анализу, была около 60.72%) на самом деле ниже средней по выборке (61.26%). Рекомендация в этом пункте напрямую противоречит твоим же собственным выводам.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Исправлено.</b>

# %% [markdown]
# ## Рекомендации бизнесу
# 1. Основные сегменты воздействия: Концерты и театр по типу мероприятия, desktop-устройства, Каменевский регион и Североярская область, Крупные билетные операторы. Предлагать таргетированную рекламму.
#
#
# 2. Сегменты пользователей, наиболее связанные с возвратом:
#  - Пользователи со средним количеством билетов 2-3 - семейные и дружеские группы - предлагать скидки и акции для семей, программы лояльности по типу "приведи друзей",
#  - Пользователи с более короткими интервалами между покупками - программы лояльности для активных паользователей - баллы, скидки и т. п.,
#  - Пользователи с большей средней выручкой - кэш-бэк в баллах.

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**
#
# https://ds-practicum.gitlab.yandexcloud.net/s3465592/module2_finalwork
#
# https://github.com/akrilov83-cmd/module2_finalwork

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты прислал ссылку на приватный репозиторий - размести, пожалуйста, на обычном `GitHub`, чтобы его можно было смотреть без авторизации.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Комментарий студента: Добавлена ссылка на публичный репозиторий на GitHub.</b>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Андрей, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
